# %%
import random
import pandas as pd
import numpy as np
import cvxpy as cp
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rc('font', family='BIZ UDGothic')

# %%
# 行動分類のラベル
large = ["必需行動", "拘束行動", "自由行動", "その他"] # 大分類
 
middle = ["睡眠", "食事", "身のまわりの用事", "療養・静養", "仕事", "仕事関連", "学業", "学校外の学習", 
  "家事", "子どもの世話", "家庭雑事", "通勤", "通学", "社会参加", "会話・交際", "スポーツ", 
  "行楽・散策", "趣味・娯楽・教養 (インターネット除く)", "趣味・娯楽・教養のインターネット (動画除く)", 
  "インターネット動画", "テレビ", "録画番組・DVD", "ラジオ", "新聞", "雑誌・マンガ・本", "音楽", "休息", "その他", "不明"]
 # 中分類
 
small = ["睡眠", "食事", "身のまわりの用事", "療養・静養", "仕事", "仕事のつきあい", "授業", "学校外の学習", 
  "炊事・掃除・洗濯", "買い物", "子どもの世話", "家庭雑事", "通勤", "通学", "社会参加", "会話・交際", 
  "スポーツ", "行楽・散策", "趣味・娯楽・教養 (インターネット除く)", "趣味・娯楽・教養のインターネット (動画除く)", 
  "インターネット動画", "テレビ", "録画番組・DVD", "ラジオ", "新聞", "雑誌・マンガ・本", "音楽", "休息", "その他", "不明"]
 # 小分類

def calc_list_diff(list1:list, list2:list):
    # リストの長さが異なる場合のエラーチェック
    if len(list1) != len(list2):
        raise ValueError("リストの長さが異なります。")
    
    # 各要素の差分を計算して新しいリストを生成
    difference = [a - b for a, b in zip(list1, list2)]
    return difference

# not P_iの計算
def get_P_i(Initial_P_i,Transition_rates,Daily_table):
    initial_rate = np.array(Initial_P_i)

    # 正規化
    initial_rate = initial_rate / np.sum(initial_rate)

    P_i_list = []
    for i in range(len(Daily_table)):

        # 行列の加工
        n = len(initial_rate)
        one_vector = np.ones(n)
        modified_transition_rates = []

        for A in Transition_rates:
            A_i = A.copy()
            A_i[i, :] = 0  # 行 i を全て 0 に置き換える
            modified_transition_rates.append(A_i)

        # 初期行為者率ベクトルの加工
        modified_initial_rate = initial_rate.copy()
        modified_initial_rate[i] = 0

        # 最終的な行為者率ベクトルの計算
        final_rate = modified_initial_rate

        for A_i in modified_transition_rates:
            final_rate = A_i @ final_rate

        # 行為 i を一度も行わない確率の計算
        P_not_i = one_vector @ final_rate

        P_i = 1-P_not_i

        P_i_list.append(P_i)

    return P_i_list

# データフレームを参照リストに基づいてソートするヘルパー関数
def sort_df_by_list(df, column, reference_list):
    return df.set_index(column).reindex(reference_list).reset_index()

# 遷移率を計算する関数
def calc_transition_rates(beta_i: np.ndarray, time_list: list, time_table: pd.DataFrame, activity_list: list):
    transition_rates = []
    middle = activity_list  # 活動のリストを基準として使用
    
    for i in range(len(time_list)):
        time_t = time_list[i]
        time_t1 = time_list[(i+1) % len(time_list)]  # 次の時間帯
        
        # 両方の時間帯の行動率を取得
        y_t = np.array(sort_df_by_list(time_table[(time_table["Time"].dt.hour == time_t.hour) & (time_table["Time"].dt.minute == time_t.minute) ], "Activity", middle)["Rate"])
        y_t1 = np.array(sort_df_by_list(time_table[(time_table["Time"].dt.hour == time_t1.hour) & (time_table["Time"].dt.minute == time_t1.minute) ], "Activity", middle)["Rate"])
        
        # 変数の定義
        no_of_elem = len(middle)
        a = cp.Variable((no_of_elem, no_of_elem), nonneg=True)  # 非負の要素を持つ遷移行列

        # 目的関数と制約条件の定義
        delta = np.eye(no_of_elem)  # クロネッカーのデルタ
        beta_i = np.ones(no_of_elem)
        # 目的関数: (1 - beta_i * delta) で修正された、二乗差の合計を最小化
        objective = cp.Minimize(cp.sum(cp.multiply(1 - beta_i * delta, cp.square(a))))

        # 行の和が1になる制約に変更
        constraints = [
            cp.sum(a, axis=1) == 1,  # 遷移行列の各行の和が1になる制約
            a >= 0,  # 非負制約
        ]

        # 行動率を正規化
        y_t = y_t / np.sum(y_t)
        y_t1 = y_t1 / np.sum(y_t1)

        # 次の時間帯の行動率と遷移行列の適用が一致する制約
        constraints.append(y_t1 - a.T @ y_t == 0)

        # 問題を定義する
        problem = cp.Problem(objective, constraints)

        # ソルバーを使用して問題を解く（別のソルバーを指定して解く）
        problem.solve(solver=cp.SCS, verbose=True)

        # 得られた遷移行列を格納
        transition_rates.append(a.value)

    return np.array(transition_rates)

def roulette_wheel_selection(weights):
    """
    Performs roulette wheel selection on a list of weights.
    
    Args:
    weights (list of float): The weights or probabilities for each item.
    
    Returns:
    int: The index of the selected item.
    """
    # Calculate the cumulative sum of weights
    cumulative_sum = [sum(weights[:i+1]) for i in range(len(weights))]
    total_sum = cumulative_sum[-1]
    
    # Generate a random number in the range [0, total_sum)
    random_num = random.uniform(0, total_sum)
    
    # Find the index where the random number would fit in the cumulative sum
    for i, cum_sum in enumerate(cumulative_sum):
        if random_num < cum_sum:
            return i

# %%
data_hourly = pd.read_csv('../data/2020_jikoku_danjonenso.csv')
data_full_day = pd.read_csv('../data/2020_4shihyo_danjonenso.csv')

# %%
data_full_day
# Out:
#        曜日       層        行動  行為者率(％) 行為者平均時間量(時間:分) 全員平均時間量(時間:分)  \
# 0      平日    男１０代        睡眠     98.9           7:40          7:35
# 1      平日    男２０代        睡眠    100.0           7:27          7:27
# 2      平日    男３０代        睡眠     99.5           7:23          7:21
# 3      平日    男４０代        睡眠     99.7           6:59          6:58
# 4      平日    男５０代        睡眠     99.4           6:56          6:54
# ...   ...     ...       ...      ...            ...           ...
# 1801  日曜日    女３０代  テレビ（専　念）     44.8           1:50          0:49
# 1802  日曜日    女４０代  テレビ（専　念）     60.0           2:09          1:18
# 1803  日曜日    女５０代  テレビ（専　念）     81.5           2:45          2:15
# 1804  日曜日    女６０代  テレビ（専　念）     89.4           3:19          2:58
# 1805  日曜日  女７０歳以上  テレビ（専　念）     89.2           3:50          3:25
#
#      全員平均時間量の標準偏差(時間:分)
# 0                  1:24
# 1                  1:14
# 2                  1:44
# 3                  1:38
# 4                  1:32
# ...                 ...
# 1801               1:25
# 1802               1:42
# 1803               2:10
# 1804               2:33
# 1805               2:46
#
# [1806 rows x 7 columns]

# %%
data_hourly = data_hourly.set_axis(["Day","Group","Activity","Time","Rate"],axis=1)
data_hourly["Time"] = pd.to_datetime(data_hourly["Time"], format="%H:%M")
data_hourly = data_hourly.query("Group == '男１０代' & Activity in @middle & Day == '平日'")
data_hourly_cleaned = data_hourly[["Activity","Time","Rate"]].copy()
data_hourly_cleaned = data_hourly_cleaned.sort_values(by="Time")

# アクティビティと時間のリストを取得
activity_list_hourly = data_hourly_cleaned['Activity'].unique()
time_list_hourly = data_hourly_cleaned['Time'].unique()

# %%
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1
#   5500| 7.63e-04  5.23e-06  2.64e-04  9.25e-02  1.00e-01  1.87e-01
#   5750| 7.63e-04  5.07e-06  2.56e-04  9.29e-02  1.00e-01  1.96e-01
#   6000| 7.62e-04  4.93e-06  2.49e-04  9.33e-02  1.00e-01  2.04e-01
#   6250| 7.62e-04  4.80e-06  2.43e-04  9.37e-02  1.00e-01  2.14e-01
#   6500| 7.61e-04  4.69e-06  2.37e-04  9.41e-02  1.00e-01  2.24e-01
#   6750| 7.59e-04  4.58e-06  2.32e-04  9.45e-02  1.00e-01  2.36e-01
#   7000| 7.58e-04  4.48e-06  2.27e-04  9.49e-02  1.00e-01  2.48e-01
#   7250| 1.24e-02  5.08e-03  3.81e-02  1.41e-01  1.00e-01  2.59e-01
#   7500| 7.54e-04  4.30e-06  2.18e-04  9.56e-02  1.00e-01  2.68e-01
#   7750| 7.52e-04  4.22e-06  2.13e-04  9.60e-02  1.00e-01  2.78e-01
#   8000| 7.50e-04  4.13e-06  2.09e-04  9.63e-02  1.00e-01  2.87e-01
#   8250| 7.48e-04  4.05e-06  2.05e-04  9.67e-02  1.00e-01  2.96e-01
#   8500| 7.46e-04  3.98e-06  2.01e-04  9.70e-02  1.00e-01  3.05e-01
#   8750| 7.43e-04  3.90e-06  1.97e-04  9.73e-02  1.00e-01  3.13e-01
#   9000| 7.38e-04  1.29e-05  2.06e-04  9.76e-02  3.17e-01  3.22e-01
#   9250| 7.21e-04  3.21e-05  5.13e-04  9.80e-02  3.17e-01  3.31e-01
#   9500| 7.09e-04  3.39e-05  5.42e-04  9.89e-02  3.17e-01  3.40e-01
#   9750| 6.97e-04  3.25e-05  5.20e-04  9.99e-02  3.17e-01  3.49e-01
#  10000| 2.69e-04  1.47e-05  6.65e-05  1.13e-01  3.17e-01  3.57e-01
#  10250| 6.45e-05  1.32e-06  1.74e-05  1.13e-01  3.17e-01  3.65e-01
#  10375| 1.63e-05  8.08e-07  1.04e-05  1.13e-01  3.17e-01  3.70e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 3.70e-01s = setup: 2.36e-03s + solve: 3.67e-01s
# 	 lin-sys: 2.27e-01s, cones: 4.71e-02s, accel: 1.66e-02s
# ------------------------------------------------------------------
# objective = 0.113006
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Sep 09 03:35:02 PM: Problem status: optimal
# (CVXPY) Sep 09 03:35:02 PM: Optimal value: 1.130e-01
# (CVXPY) Sep 09 03:35:02 PM: Compilation took 1.249e-02 seconds
# (CVXPY) Sep 09 03:35:02 PM: Solver (including time spent in interface) took 3.703e-01 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.5.2
# ===============================================================================
# (CVXPY) Sep 09 03:35:02 PM: Your problem has 576 variables, 624 constraints, and 0 parameters.
# (CVXPY) Sep 09 03:35:02 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Sep 09 03:35:02 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Sep 09 03:35:02 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Sep 09 03:35:02 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Sep 09 03:35:02 PM: Compiling problem (target solver=SCS).
# (CVXPY) Sep 09 03:35:02 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Sep 09 03:35:02 PM: Applying reduction Dcp2Cone
# (CVXPY) Sep 09 03:35:02 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Sep 09 03:35:02 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Sep 09 03:35:02 PM: Applying reduction SCS
# (CVXPY) Sep 09 03:35:02 PM: Finished problem compilation (took 2.502e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Sep 09 03:35:02 PM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.4 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n:
#  24250| 1.52e-04  2.84e-06  4.60e-05  2.14e-01  3.17e-01  9.80e-01
#  24500| 1.46e-04  2.71e-06  4.38e-05  2.14e-01  3.17e-01  9.89e-01
#  24750| 1.40e-04  2.58e-06  4.17e-05  2.14e-01  3.17e-01  9.98e-01
#  25000| 1.34e-04  2.45e-06  3.97e-05  2.14e-01  3.17e-01  1.01e+00
#  25250| 1.29e-04  2.34e-06  3.78e-05  2.14e-01  3.17e-01  1.02e+00
#  25500| 1.26e-04  1.63e-04  2.60e-04  2.15e-01  3.17e-01  1.03e+00
#  25750| 1.19e-04  2.12e-06  3.43e-05  2.14e-01  3.17e-01  1.04e+00
#  26000| 1.14e-04  2.02e-06  3.27e-05  2.14e-01  3.17e-01  1.05e+00
#  26250| 1.09e-04  1.92e-06  3.11e-05  2.14e-01  3.17e-01  1.06e+00
#  26500| 1.05e-04  1.83e-06  2.96e-05  2.14e-01  3.17e-01  1.07e+00
#  26750| 1.00e-04  1.74e-06  2.82e-05  2.14e-01  3.17e-01  1.08e+00
#  27000| 9.60e-05  1.66e-06  2.69e-05  2.14e-01  3.17e-01  1.09e+00
#  27250| 9.19e-05  1.58e-06  2.56e-05  2.14e-01  3.17e-01  1.09e+00
#  27400| 3.00e-06  7.58e-07  1.13e-05  2.15e-01  3.17e-01  1.10e+00
# ------------------------------------------------------------------
# status:  solved
# timings: total: 1.10e+00s = setup: 3.60e-03s + solve: 1.10e+00s
# 	 lin-sys: 6.76e-01s, cones: 1.47e-01s, accel: 4.55e-02s
# ------------------------------------------------------------------
# objective = 0.214570
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Sep 09 03:35:04 PM: Problem status: optimal
# (CVXPY) Sep 09 03:35:04 PM: Optimal value: 2.146e-01
# (CVXPY) Sep 09 03:35:04 PM: Compilation took 2.502e-02 seconds
# (CVXPY) Sep 09 03:35:04 PM: Solver (including time spent in interface) took 1.103e+00 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.5.2
# ===============================================================================
# (CVXPY) Sep 09 03:35:04 PM: Your problem has 576 variables, 624 constraints, and 0 parameters.
# (CVXPY) Sep 09 03:35:04 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Sep 09 03:35:04 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Sep 09 03:35:04 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Sep 09 03:35:04 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Sep 09 03:35:04 PM: Compiling problem (target solver=SCS).
# (CVXPY) Sep 09 03:35:04 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Sep 09 03:35:04 PM: Applying reduction Dcp2Cone
# (CVXPY) Sep 09 03:35:04 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Sep 09 03:35:04 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Sep 09 03:35:04 PM: Applying reduction SCS
# (CVXPY) Sep 09 03:35:04 PM: Finished problem compilation (took 2.239e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Sep 09 03:35:04 PM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.4 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 576, constraints m: 1200
# cones: 	  z: primal zero / dual free vars: 48
# 	  l: linear vars: 1152
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 1944, nnz(P): 552
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 9.99e-01  3.98e-01  1.05e-01  1.77e+00  1.00e-01  3.72e-03
#     25| 5.30e-07  2.40e-07  1.02e-06  5.10e-07  1.00e-01  4.66e-03
# ------------------------------------------------------------------
# status:  solved
# timings: total: 4.68e-03s = setup: 3.16e-03s + solve: 1.52e-03s
# 	 lin-sys: 6.08e-04s, cones: 1.22e-04s, accel: 1.66e-05s
# ------------------------------------------------------------------
# objective = 0.000001
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Sep 09 03:35:04 PM: Problem status: optimal
# (CVXPY) Sep 09 03:35:04 PM: Optimal value: 1.149e-11
# (CVXPY) Sep 09 03:35:04 PM: Compilation took 2.239e-02 seconds
# (CVXPY) Sep 09 03:35:04 PM: Solver (including time spent in interface) took 6.419e-03 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.5.2
# ===============================================================================
# (CVXPY) Sep 09 03:35:04 PM: Your problem has 576 variables, 624 constraints, and 0 parameters.
# (CVXPY) Sep 09 03:35:04 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Sep 09 03:35:04 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Sep 09 03:35:04 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Sep 09 03:35:04 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Sep 09 03:35:04 PM: Compiling problem (target solver=SCS).
# (CVXPY) Sep 09 03:35:04 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Sep 09 03:35:04 PM: Applying reduction Dcp2Cone
# (CVXPY) Sep 09 03:35:04 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Sep 09 03:35:04 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Sep 09 03:35:04 PM: Applying reduction SCS
# (CVXPY) Sep 09 03:35:04 PM: Finished problem compilation (took 2.212e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Sep 09 03:35:04 PM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.4 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 576, constraints m: 1200
# cones: 	  z: primal zero / dual free vars: 48
# 	  l: linear vars: 1152
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 1944, nnz(P): 552
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 9.99e-01  4.09e-01  1.28e-01  1.78e+00  1.00e-01  3.62e-03
#    250| 1.44e-03  1.45e-04  7.45e-03  3.40e-02  1.00e-01  1.52e-02
#    500| 2.24e-03  1.92e-04  9.88e-03  4.29e-02  1.00e-01  2.46e-02
#    750| 8.14e-03  1.19e-04  3.47e-03  3.44e-01  1.00e-01  3.51e-02
#   1000| 8.99e-04  1.03e-05  2.42e-05  3.76e-01  1.00e-01  4.51e-02
#   1250| 7.49e-04  4.02e-06  2.67e-06  3.76e-01  1.00e-01  5.39e-02
#   1500| 6.34e-04  1.61e-06  7.09e-06  3.76e-01  1.00e-01  6.44e-02
#   1750| 2.82e-05  3.17e-04  1.13e-04  3.77e-01  1.78e+00  7.54e-02
#   1800| 1.01e-05  1.35e-05  6.70e-06  3.77e-01  1.78e+00  7.74e-02
# ------------------------------------------------------------------
# status:  solved
# timings: total: 7.74e-02s = setup: 3.03e-03s + solve: 7.43e-02s
# 	 lin-sys: 4.53e-02s, cones: 9.89e-03s, accel: 3.23e-03s
# ------------------------------------------------------------------
# objective = 0.376681
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Sep 09 03:35:04 PM: Problem status: optimal
# (CVXPY) Sep 09 03:35:04 PM: Optimal value: 3.767e-01
# (CVXPY) Sep 09 03:35:04 PM: Compilation took 2.212e-02 seconds
# (CVXPY) Sep 09 03:35:04 PM: Solver (including time spent in interface) took 8.067e-02 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.5.2
# ===============================================================================
# (CVXPY) Sep 09 03:35:04 PM: Your problem has 576 variables, 624 constraints, and 0 parameters.
# (CVXPY) Sep 09 03:35:04 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Sep 09 03:35:04 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Sep 09 03:35:04 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Sep 09 03:35:04 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Sep 09 03:35:04 PM: Compiling problem (target solver=SCS).
# (CVXPY) Sep 09 03:35:04 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Sep 09 03:35:04 PM: Applying reduction Dcp2Cone
# (CVXPY) Sep 09 03:35:04 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Sep 09 03:35:04 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Sep 09 03:35:04 PM: Applying reduction SCS
# (CVXPY) Sep 09 03:35:04 PM: Finished problem compilation (took 3.702e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Sep 09 03:35:04 PM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.4 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 576, constraints m: 1200
# cones: 	  z: primal zero / dual free vars: 48
# 	  l: linear vars: 1152
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 1944, nnz(P): 552
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 9.99e-01  3.98e-01  1.05e-01  1.77e+00  1.00e-01  7.66e-03
#     25| 4.31e-07  2.00e-07  6.67e-07  3.34e-07  1.00e-01  9.48e-03
# ------------------------------------------------------------------
# status:  solved
# timings: total: 9.50e-03s = setup: 6.32e-03s + solve: 3.19e-03s
# 	 lin-sys: 1.05e-03s, cones: 2.64e-04s, accel: 3.00e-05s
# ------------------------------------------------------------------
# objective = 0.000000
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Sep 09 03:35:04 PM: Problem status: optimal
# (CVXPY) Sep 09 03:35:04 PM: Optimal value: 5.566e-12
# (CVXPY) Sep 09 03:35:04 PM: Compilation took 3.702e-02 seconds
# (CVXPY) Sep 09 03:35:04 PM: Solver (including time spent in interface) took 1.267e-02 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.5.2
# ===============================================================================
# (CVXPY) Sep 09 03:35:04 PM: Your problem has 576 variables, 624 constraints, and 0 parameters.
# (CVXPY) Sep 09 03:35:04 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Sep 09 03:35:04 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Sep 09 03:35:04 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Sep 09 03:35:04 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Sep 09 03:35:04 PM: Compiling problem (target solver=SCS).
# (CVXPY) Sep 09 03:35:04 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Sep 09 03:35:04 PM: Applying reduction Dcp2Cone
# (CVXPY) Sep 09 03:35:04 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Sep 09 03:35:04 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Sep 09 03:35:04 PM: Applying reduction SCS
# (CVXPY) Sep 09 03:35:04 PM: Finished problem compilation (took 2.811e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Sep 09 03:35:04 PM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.4 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 576, constraints m: 1200
# cones: 	  z: primal zero / dual free vars: 48
# 	  l: linear vars: 1152
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 1944, nnz(P): 552
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 9.99e-01  4.00e-01  1.10e-01  1.77e+00  1.00e-01  4.47e-03
#    250| 2.29e-04  6.01e-06  2.98e-04  2.50e-03  1.00e-01  1.53e-02
#    500| 2.29e-04  8.44e-06  4.21e-04  2.56e-03  1.00e-01  2.54e-02
#    750| 2.29e-04  1.07e-05  5.36e-04  2.63e-03  1.00e-01  3.77e-02
#   1000| 2.06e-01  4.28e-02  6.90e-02  4.65e-02  1.00e-01  4.97e-02
#   1250| 2.30e-04  1.53e-05  7.66e-04  2.79e-03  1.00e-01  6.11e-02
#   1500| 2.30e-04  1.77e-05  8.87e-04  2.88e-03  1.00e-01  7.04e-02
#   1750| 2.31e-04  2.02e-05  1.01e-03  2.98e-03  1.00e-01  7.94e-02
#   2000| 2.31e-04  2.28e-05  1.15e-03  3.08e-03  1.00e-01  8.92e-02
#   2250| 2.32e-04  2.57e-05  1.29e-03  3.19e-03  1.00e-01  1.01e-01
#   2500| 2.33e-04  2.87e-05  1.44e-03  3.31e-03  1.00e-01  1.14e-01
#   2750| 2.33e-04  3.21e-05  1.61e-03  3.45e-03  1.00e-01  1.25e-01
#   3000| 2.34e-04  3.57e-05  1.79e-03  3.60e-03  1.00e-01  1.36e-01
#   3250| 2.34e-04  3.97e-05  2.00e-03  3.77e-03  1.00e-01  1.47e-01
#   3500| 2.44e-04  4.42e-05  2.22e-03  3.97e-03  1.00e-01  1.58e-01
#   3750| 4.43e-05  1.23e-06  5.06e-05  2.59e-02  1.00e-01  1.69e-01
#   3825| 1.99e-06  5.89e-07  7.26e-06  2.58e-02  1.00e-01  1.72e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 1.72e-01s = setup: 3.86e-03s + solve: 1.68e-01s
# 	 lin-sys: 1.02e-01s, cones: 2.26e-02s, accel: 7.58e-03s
# ------------------------------------------------------------------
# objective = 0.025834
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Sep 09 03:35:04 PM: Problem status: optimal
# (CVXPY) Sep 09 03:35:04 PM: Optimal value: 2.583e-02
# (CVXPY) Sep 09 03:35:04 PM: Compilation took 2.811e-02 seconds
# (CVXPY) Sep 09 03:35:04 PM: Solver (including time spent in interface) took 1.740e-01 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.5.2
# ===============================================================================
# (CVXPY) Sep 09 03:35:04 PM: Your problem has 576 variables, 624 constraints, and 0 parameters.
# (CVXPY) Sep 09 03:35:04 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Sep 09 03:35:04 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Sep 09 03:35:04 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Sep 09 03:35:04 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Sep 09 03:35:04 PM: Compiling problem (target solver=SCS).
# (CVXPY) Sep 09 03:35:04 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Sep 09 03:35:04 PM: Applying reduction Dcp2Cone
# (CVXPY) Sep 09 03:35:04 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Sep 09 03:35:04 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Sep 09 03:35:04 PM: Applying reduction SCS
# (CVXPY) Sep 09 03:35:04 PM: Finished problem compilation (took 2.197e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Sep 09 03:35:04 PM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.4 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 576, constraints m: 1200
# cones: 	  z: primal zero / dual free vars: 48
# 	  l: linear vars: 1152
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 1944, nnz(P): 552
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 9.99e-01  3.98e-01  1.05e-01  1.77e+00  1.00e-01  4.03e-03
#     25| 3.83e-07  1.50e-07  6.09e-07  3.05e-07  1.00e-01  5.17e-03
# ------------------------------------------------------------------
# status:  solved
# timings: total: 5.20e-03s = setup: 3.31e-03s + solve: 1.88e-03s
# 	 lin-sys: 6.78e-04s, cones: 1.59e-04s, accel: 2.59e-05s
# ------------------------------------------------------------------
# objective = 0.000000
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Sep 09 03:35:04 PM: Problem status: optimal
# (CVXPY) Sep 09 03:35:04 PM: Optimal value: 4.763e-12
# (CVXPY) Sep 09 03:35:04 PM: Compilation took 2.197e-02 seconds
# (CVXPY) Sep 09 03:35:04 PM: Solver (including time spent in interface) took 6.806e-03 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.5.2
# ===============================================================================
# (CVXPY) Sep 09 03:35:04 PM: Your problem has 576 variables, 624 constraints, and 0 parameters.
# (CVXPY) Sep 09 03:35:04 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Sep 09 03:35:04 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Sep 09 03:35:04 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Sep 09 03:35:04 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Sep 09 03:35:04 PM: Compiling problem (target solver=SCS).
# (CVXPY) Sep 09 03:35:04 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Sep 09 03:35:04 PM: Applying reduction Dcp2Cone
# (CVXPY) Sep 09 03:35:04 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Sep 09 03:35:04 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Sep 09 03:35:04 PM: Applying reduction SCS
# (CVXPY) Sep 09 03:35:04 PM: Finished problem compilation (took 2.420e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Sep 09 03:35:04 PM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.4 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 576, constraints m: 1200
# cones: 	  z: primal zero / dual free vars: 48
# 	  l: linear vars: 1152
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 1944, nnz(P): 552
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 9.99e-01  4.12e-01  1.33e-01  1.79e+00  1.00e-01  4.08e-03
#    250| 4.47e-03  1.86e-03  9.67e-02  2.58e-01  1.00e-01  1.48e-02
#    500| 1.51e-02  3.44e-05  1.30e-03  1.24e+00  1.00e-01  2.54e-02
#    750| 1.43e-02  3.07e-04  3.52e-03  1.31e+00  3.18e-01  3.51e-02
#   1000| 4.68e-03  2.86e-03  4.96e-03  1.57e+00  1.86e+00  4.71e-02
#   1250| 1.63e-04  5.38e-04  1.10e-03  1.67e+00  1.86e+00  5.87e-02
#   1450| 1.78e-06  6.14e-06  1.49e-05  1.68e+00  1.86e+00  6.81e-02
# ------------------------------------------------------------------
# status:  solved
# timings: total: 6.81e-02s = setup: 3.50e-03s + solve: 6.46e-02s
# 	 lin-sys: 3.89e-02s, cones: 8.65e-03s, accel: 2.79e-03s
# ------------------------------------------------------------------
# objective = 1.676130
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Sep 09 03:35:04 PM: Problem status: optimal
# (CVXPY) Sep 09 03:35:04 PM: Optimal value: 1.676e+00
# (CVXPY) Sep 09 03:35:04 PM: Compilation took 2.420e-02 seconds
# (CVXPY) Sep 09 03:35:04 PM: Solver (including time spent in interface) took 7.082e-02 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.5.2
# ===============================================================================
# (CVXPY) Sep 09 03:35:04 PM: Your problem has 576 variables, 624 constraints, and 0 parameters.
# (CVXPY) Sep 09 03:35:04 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Sep 09 03:35:04 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Sep 09 03:35:04 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Sep 09 03:35:04 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Sep 09 03:35:04 PM: Compiling problem (target solver=SCS).
# (CVXPY) Sep 09 03:35:04 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Sep 09 03:35:04 PM: Applying reduction Dcp2Cone
# (CVXPY) Sep 09 03:35:04 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Sep 09 03:35:04 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Sep 09 03:35:04 PM: Applying reduction SCS
# (CVXPY) Sep 09 03:35:04 PM: Finished problem compilation (took 2.274e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Sep 09 03:35:04 PM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.4 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 576, constraints m: 1200
# cones: 	  z: primal zero / dual free vars: 48
# 	  l: linear vars: 1152
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 1848, nnz(P): 552
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 9.99e-01  3.99e-01  1.07e-01  1.77e+00  1.00e-01  5.73e-03
#     25| 4.13e-07  1.87e-07  3.93e-07  1.96e-07  1.00e-01  7.28e-03
# ------------------------------------------------------------------
# status:  solved
# timings: total: 7.31e-03s = setup: 4.14e-03s + solve: 3.17e-03s
# 	 lin-sys: 9.45e-04s, cones: 2.32e-04s, accel: 3.02e-05s
# ------------------------------------------------------------------
# objective = 0.000000
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Sep 09 03:35:04 PM: Problem status: optimal
# (CVXPY) Sep 09 03:35:04 PM: Optimal value: 1.884e-12
# (CVXPY) Sep 09 03:35:04 PM: Compilation took 2.274e-02 seconds
# (CVXPY) Sep 09 03:35:04 PM: Solver (including time spent in interface) took 9.482e-03 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.5.2
# ===============================================================================
# (CVXPY) Sep 09 03:35:04 PM: Your problem has 576 variables, 624 constraints, and 0 parameters.
# (CVXPY) Sep 09 03:35:04 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Sep 09 03:35:04 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Sep 09 03:35:04 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Sep 09 03:35:04 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Sep 09 03:35:04 PM: Compiling problem (target solver=SCS).
# (CVXPY) Sep 09 03:35:04 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Sep 09 03:35:04 PM: Applying reduction Dcp2Cone
# (CVXPY) Sep 09 03:35:04 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Sep 09 03:35:04 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Sep 09 03:35:04 PM: Applying reduction SCS
# (CVXPY) Sep 09 03:35:04 PM: Finished problem compilation (took 4.967e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Sep 09 03:35:04 PM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.4 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 576, constraints m: 1200
# cones: 	  z: primal zero / dual free vars: 48
# 	  l: linear vars: 1152
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# ...
# (CVXPY) Sep 09 03:35:36 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Sep 09 03:35:36 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Sep 09 03:35:36 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Sep 09 03:35:36 PM: Compiling problem (target solver=SCS).
# (CVXPY) Sep 09 03:35:36 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Sep 09 03:35:36 PM: Applying reduction Dcp2Cone
# (CVXPY) Sep 09 03:35:36 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Sep 09 03:35:36 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Sep 09 03:35:36 PM: Applying reduction SCS
# (CVXPY) Sep 09 03:35:36 PM: Finished problem compilation (took 1.983e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Sep 09 03:35:36 PM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.4 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 576, constraints m: 1200
# cones: 	  z: primal zero / dual free vars: 48
# 	  l: linear vars: 1152
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 2016, nnz(P): 552
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 1.00e+00  4.53e-01  2.50e-01  1.86e+00  1.00e-01  5.76e-03
#    250| 1.03e-02  1.90e-04  2.36e-03  4.88e-01  1.00e-01  2.27e-02
#    500| 4.84e-03  1.10e-04  5.22e-03  5.18e-01  1.00e-01  3.93e-02
#    750| 4.80e-03  9.26e-05  4.56e-03  5.46e-01  1.00e-01  5.17e-02
#   1000| 3.36e-03  4.93e-04  8.83e-03  5.94e-01  3.17e-01  6.28e-02
#   1250| 3.07e-03  4.21e-04  7.98e-03  6.34e-01  3.17e-01  7.26e-02
#   1500| 2.42e-03  2.41e-04  4.89e-03  6.63e-01  3.17e-01  8.49e-02
#   1750| 1.79e-03  1.97e-04  4.11e-03  6.76e-01  3.17e-01  9.54e-02
#   2000| 1.99e-03  1.61e-04  3.34e-03  6.86e-01  3.17e-01  1.05e-01
#   2250| 3.65e-04  7.10e-05  1.31e-03  7.13e-01  3.17e-01  1.15e-01
#   2500| 1.50e-04  4.27e-06  1.00e-05  7.15e-01  3.17e-01  1.25e-01
#   2575| 1.82e-06  3.31e-07  3.73e-06  7.15e-01  3.17e-01  1.29e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 1.29e-01s = setup: 4.74e-03s + solve: 1.24e-01s
# 	 lin-sys: 7.55e-02s, cones: 1.60e-02s, accel: 5.58e-03s
# ------------------------------------------------------------------
# objective = 0.715372
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Sep 09 03:35:37 PM: Problem status: optimal
# (CVXPY) Sep 09 03:35:37 PM: Optimal value: 7.154e-01
# (CVXPY) Sep 09 03:35:37 PM: Compilation took 1.983e-02 seconds
# (CVXPY) Sep 09 03:35:37 PM: Solver (including time spent in interface) took 1.305e-01 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.5.2
# ===============================================================================
# (CVXPY) Sep 09 03:35:37 PM: Your problem has 576 variables, 624 constraints, and 0 parameters.
# (CVXPY) Sep 09 03:35:37 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Sep 09 03:35:37 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Sep 09 03:35:37 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Sep 09 03:35:37 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Sep 09 03:35:37 PM: Compiling problem (target solver=SCS).
# (CVXPY) Sep 09 03:35:37 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Sep 09 03:35:37 PM: Applying reduction Dcp2Cone
# (CVXPY) Sep 09 03:35:37 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Sep 09 03:35:37 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Sep 09 03:35:37 PM: Applying reduction SCS
# (CVXPY) Sep 09 03:35:37 PM: Finished problem compilation (took 2.828e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Sep 09 03:35:37 PM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.4 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 576, constraints m: 1200
# cones: 	  z: primal zero / dual free vars: 48
# 	  l: linear vars: 1152
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 1944, nnz(P): 552
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 1.00e+00  4.20e-01  1.66e-01  1.81e+00  1.00e-01  6.65e-03
#    250| 3.45e-03  4.22e-04  2.23e-02  3.73e-02  1.00e-01  3.51e-02
#    500| 4.39e-03  8.30e-05  4.40e-03  1.68e-01  1.00e-01  5.25e-02
#    750| 6.06e-04  8.02e-06  9.35e-06  1.80e-01  1.00e-01  6.71e-02
#   1000| 2.77e-04  4.85e-06  1.66e-04  1.80e-01  1.00e-01  7.88e-02
#   1250| 2.09e-04  2.85e-06  1.52e-04  1.80e-01  1.00e-01  8.90e-02
#   1500| 1.86e-04  2.52e-06  1.43e-04  1.80e-01  1.00e-01  1.01e-01
#   1750| 1.73e-04  2.38e-06  1.35e-04  1.80e-01  1.00e-01  1.12e-01
#   2000| 1.63e-04  2.26e-06  1.28e-04  1.80e-01  1.00e-01  1.21e-01
#   2250| 4.81e-06  8.07e-07  2.86e-06  1.81e-01  3.17e-01  1.31e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 1.31e-01s = setup: 5.30e-03s + solve: 1.26e-01s
# 	 lin-sys: 6.83e-02s, cones: 1.51e-02s, accel: 1.76e-02s
# ------------------------------------------------------------------
# objective = 0.180926
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Sep 09 03:35:37 PM: Problem status: optimal
# (CVXPY) Sep 09 03:35:37 PM: Optimal value: 1.809e-01
# (CVXPY) Sep 09 03:35:37 PM: Compilation took 2.828e-02 seconds
# (CVXPY) Sep 09 03:35:37 PM: Solver (including time spent in interface) took 1.342e-01 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.5.2
# ===============================================================================
# (CVXPY) Sep 09 03:35:37 PM: Your problem has 576 variables, 624 constraints, and 0 parameters.
# (CVXPY) Sep 09 03:35:37 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Sep 09 03:35:37 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Sep 09 03:35:37 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Sep 09 03:35:37 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Sep 09 03:35:37 PM: Compiling problem (target solver=SCS).
# (CVXPY) Sep 09 03:35:37 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Sep 09 03:35:37 PM: Applying reduction Dcp2Cone
# (CVXPY) Sep 09 03:35:37 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Sep 09 03:35:37 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Sep 09 03:35:37 PM: Applying reduction SCS
# (CVXPY) Sep 09 03:35:37 PM: Finished problem compilation (took 1.969e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Sep 09 03:35:37 PM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.4 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 576, constraints m: 1200
# cones: 	  z: primal zero / dual free vars: 48
# 	  l: linear vars: 1152
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 2016, nnz(P): 552
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 1.00e+00  4.62e-01  2.37e-01  1.84e+00  1.00e-01  5.05e-03
#    250| 3.37e-02  3.41e-03  2.01e-01  7.12e-01  1.00e-01  1.70e-02
#    500| 1.74e-02  1.82e-04  3.80e-03  1.50e+00  1.00e-01  3.08e-02
#    750| 4.19e-03  5.93e-02  1.34e-02  1.67e+00  2.27e+00  5.37e-02
#   1000| 5.79e-04  1.53e-03  3.45e-03  1.72e+00  2.27e+00  1.15e-01
#   1250| 5.12e-04  1.35e-03  2.98e-03  1.74e+00  2.27e+00  1.31e-01
#   1500| 9.31e-05  7.95e-04  7.48e-05  1.80e+00  2.27e+00  1.48e-01
#   1550| 8.39e-06  2.27e-05  5.63e-06  1.80e+00  2.27e+00  1.51e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 1.51e-01s = setup: 4.44e-03s + solve: 1.46e-01s
# 	 lin-sys: 6.12e-02s, cones: 1.29e-02s, accel: 4.29e-02s
# ------------------------------------------------------------------
# objective = 1.798048
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Sep 09 03:35:37 PM: Problem status: optimal
# (CVXPY) Sep 09 03:35:37 PM: Optimal value: 1.798e+00
# (CVXPY) Sep 09 03:35:37 PM: Compilation took 1.969e-02 seconds
# (CVXPY) Sep 09 03:35:37 PM: Solver (including time spent in interface) took 1.537e-01 seconds
# [[[1.00001413e+00 8.52524607e-06 0.00000000e+00 ... 0.00000000e+00
#    1.07718429e-05 8.52524599e-06]
#   [2.97308869e-02 9.45423481e-01 0.00000000e+00 ... 0.00000000e+00
#    3.12291402e-08 2.69268991e-09]
#   [3.11441598e-09 3.11441597e-09 9.99999928e-01 ... 3.11441597e-09
#    3.11441597e-09 3.11441597e-09]
#   ...
#   [3.11441587e-09 3.11441586e-09 3.11441586e-09 ... 9.99999928e-01
#    3.11441586e-09 3.11441586e-09]
#   [2.20999206e-02 8.58584739e-03 0.00000000e+00 ... 0.00000000e+00
#    9.06505728e-01 8.58584739e-03]
#   [2.97308869e-02 2.69269179e-09 0.00000000e+00 ... 0.00000000e+00
#    3.12291412e-08 9.45423481e-01]]
#
#  [[9.99996679e-01 4.55232402e-07 0.00000000e+00 ... 0.00000000e+00
#    3.00475866e-06 4.55232405e-07]
#   [6.80282795e-02 8.76395094e-01 0.00000000e+00 ... 0.00000000e+00
#    2.78025765e-08 3.60425594e-07]
#   [3.78471214e-07 3.78471214e-07 9.99991295e-01 ... 3.78471214e-07
#    3.78471214e-07 3.78471214e-07]
#   ...
#   [3.78471214e-07 3.78471214e-07 3.78471214e-07 ... 9.99991295e-01
#    3.78471214e-07 3.78471214e-07]
#   [4.61089208e-02 1.51871394e-02 0.00000000e+00 ... 0.00000000e+00
#    8.37507240e-01 1.51871394e-02]
#   [6.80282795e-02 3.60425531e-07 0.00000000e+00 ... 0.00000000e+00
#    2.78025764e-08 8.76395094e-01]]
#
#  [[9.99999977e-01 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#    0.00000000e+00 0.00000000e+00]
#   [3.91514796e-07 9.99996368e-01 3.27384571e-08 ... 3.27384571e-08
#    3.85698719e-07 3.90551363e-07]
#   [0.00000000e+00 0.00000000e+00 1.00000003e+00 ... 0.00000000e+00
#    0.00000000e+00 0.00000000e+00]
#   ...
#   [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 1.00000003e+00
#    0.00000000e+00 0.00000000e+00]
#   [1.78260585e-07 1.76539996e-07 0.00000000e+00 ... 0.00000000e+00
#    9.99998886e-01 1.76539996e-07]
#   [3.91514796e-07 3.90551363e-07 3.27384571e-08 ... 3.27384571e-08
#    3.85698719e-07 9.99996368e-01]]
#
#  ...
#
#  [[9.99995081e-01 1.82130356e-06 0.00000000e+00 ... 4.16369876e-08
#    0.00000000e+00 1.22525405e-06]
#   [7.67529691e-02 8.52197738e-01 0.00000000e+00 ... 0.00000000e+00
#    0.00000000e+00 1.17573370e-02]
#   [6.37296524e-08 6.37296523e-08 9.99998534e-01 ... 6.37296523e-08
#    6.37296523e-08 6.37296523e-08]
#   ...
#   [1.32981476e-01 1.08996179e-01 5.11310215e-06 ... 0.00000000e+00
#    8.17808905e-02 1.12670341e-01]
#   [5.12005272e-02 2.72152298e-02 8.84493092e-09 ... 9.56579797e-09
#    7.36089616e-01 3.08893921e-02]
#   [1.29991295e-01 2.06573770e-08 0.00000000e+00 ... 0.00000000e+00
#    0.00000000e+00 8.43113681e-01]]
#
#  [[9.99997779e-01 0.00000000e+00 0.00000000e+00 ... 2.65565996e-07
#    4.80831299e-06 1.95548395e-06]
#   [7.83745366e-02 6.84109092e-01 0.00000000e+00 ... 3.06230178e-02
#    1.21397215e-02 1.26553244e-02]
#   [0.00000000e+00 0.00000000e+00 1.00000040e+00 ... 0.00000000e+00
#    0.00000000e+00 0.00000000e+00]
#   ...
#   [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 1.00000040e+00
#    0.00000000e+00 0.00000000e+00]
#   [2.06985196e-02 0.00000000e+00 0.00000000e+00 ... 5.77616999e-03
#    9.42784706e-01 1.61265785e-04]
#   [1.31438606e-01 0.00000000e+00 0.00000000e+00 ... 3.59355684e-02
#    1.44895200e-07 6.43105575e-01]]
#
#  [[9.99988668e-01 8.39290096e-06 2.94063241e-08 ... 2.93982672e-08
#    0.00000000e+00 0.00000000e+00]
#   [1.54544240e-01 7.97514567e-01 0.00000000e+00 ... 0.00000000e+00
#    0.00000000e+00 0.00000000e+00]
#   [8.21251793e-06 8.21251793e-06 9.99811112e-01 ... 8.21251793e-06
#    8.21251793e-06 8.21251793e-06]
#   ...
#   [1.55719734e-01 8.54780169e-02 1.06971722e-09 ... 2.25057391e-09
#    7.43914834e-02 8.04323314e-02]
#   [8.13290083e-02 1.10872912e-02 0.00000000e+00 ... 0.00000000e+00
#    8.18298766e-01 6.04160579e-03]
#   [3.16206257e-01 2.11910447e-02 0.00000000e+00 ... 0.00000000e+00
#    0.00000000e+00 4.65237166e-01]]]

# %% [markdown]
# 可視化

# %%
# ヒートマップを描画する関数
def plot_transition_heatmaps(transition_rates, activity_list, time_list):
    num_time_intervals = len(time_list)
    num_activities = len(activity_list)

    # 時間ごとにヒートマップを描画
    fig, axes = plt.subplots(nrows=5, ncols=5, figsize=(20, 20))
    axes = axes.flatten()  # 5x5のグリッドにして1次元に展開

    for i in range(min(num_time_intervals, 25)):  # 最大25時間分描画
        ax = axes[i]
        sns.heatmap(transition_rates[i], annot=False, cmap='coolwarm', cbar=True, vmin=0, vmax=1, ax=ax)
        ax.set_title(f"{i}-{(i+1)%24}時", fontsize=10)
        ax.set_xticks(np.arange(len(activity_list)) + 0.5)
        ax.set_yticks(np.arange(len(activity_list)) + 0.5)
        ax.set_xticklabels(activity_list, rotation=90, fontsize=8)
        ax.set_yticklabels(activity_list, rotation=0, fontsize=8)
    
    plt.tight_layout()
    plt.show()

# %%
# 先ほど計算した transition_rates_hourly を使用してヒートマップを作成
plot_transition_heatmaps(transition_rates_hourly, activity_list_hourly, time_list_hourly)

# %%
import random

# %%
def roulette_wheel_selection(weights):
    """
    Performs roulette wheel selection on a list of weights.
    
    Args:
    weights (list of float): The weights or probabilities for each item.
    
    Returns:
    int: The index of the selected item.
    """
    # Calculate the cumulative sum of weights
    cumulative_sum = [sum(weights[:i+1]) for i in range(len(weights))]
    total_sum = cumulative_sum[-1]
    
    # Generate a random number in the range [0, total_sum)
    random_num = random.uniform(0, total_sum)
    
    # Find the index where the random number would fit in the cumulative sum
    for i, cum_sum in enumerate(cumulative_sum):
        if random_num < cum_sum:
            return i

# %%
activity_list_hourly
# Out:
# array(['睡眠', '休息', '療養・静養', '仕事関連', '仕事', '音楽', '学業', '学校外の学習', '家事',
#        '雑誌・マンガ・本', '身のまわりの用事', '子どもの世話', '通勤', '新聞', '通学', '社会参加',
#        '会話・交際', 'ラジオ', 'スポーツ', '行楽・散策', 'インターネット動画', '家庭雑事', '食事', 'テレビ'],
#       dtype=object)

# %%
# 初期行動の規定
time_table_0 = data_hourly_cleaned[(data_hourly_cleaned["Time"].dt.hour == 0) & (data_hourly_cleaned["Time"].dt.minute == 0)] # 0:00における行為者率を抽出
action_idx = roulette_wheel_selection(time_table_0["Rate"].to_list()) # その時刻における行為者率を重みとしてルーレット選択
Actions =[] # 選択した行為種別の記録
Actions.append(action_idx)
for t in range(4*24): # 15min間隔で24時間分繰り返す。
    transition_r_t = transition_rates_hourly[t] # 時刻tの遷移確率行列を抽出
    action_idx = roulette_wheel_selection(list(transition_r_t[action_idx,:])) # 遷移確率をもとにt+1における行動種別を決定
    Actions.append(action_idx) # 行動種別履歴に追加
acts = middle
actMaster = dict(zip(list(range(len(acts))),acts))
print([actMaster[a] for a in Actions])
# Out:
# ['テレビ', 'テレビ', 'テレビ', 'テレビ', '睡眠', '睡眠', '睡眠', '睡眠', '睡眠', '睡眠', '睡眠', '睡眠', '睡眠', '睡眠', '睡眠', '睡眠', '睡眠', '睡眠', '睡眠', '睡眠', '睡眠', '睡眠', '睡眠', '睡眠', '睡眠', '睡眠', '睡眠', '睡眠', '睡眠', 'ラジオ', 'ラジオ', '会話・交際', '学業', '学業', '学業', '学業', '学業', '学業', '学業', '学業', '学業', '学業', '学業', '学業', '学業', '学業', '学業', '学業', '学業', '学業', '学業', '学業', '学業', '学業', '学業', '学業', '学業', '学業', '学業', '学業', '学業', '学業', '学業', '学業', '学業', '学業', '学業', '学業', '学業', '学業', '学業', '学業', '学業', 'ラジオ', 'ラジオ', 'ラジオ', 'ラジオ', 'ラジオ', 'ラジオ', 'ラジオ', 'ラジオ', 'ラジオ', '家庭雑事', '家庭雑事', '家庭雑事', '家庭雑事', '家庭雑事', '家庭雑事', '家庭雑事', '家庭雑事', '家庭雑事', '家庭雑事', '家庭雑事', '家庭雑事', '新聞', '新聞', '睡眠']

# %%
get_P_i(transition_rates_hourly, )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 get_P_i(transition_rates_hourly)
#
# TypeError: get_P_i() missing 2 required positional arguments: 'Transition_rates' and 'Daily_table'
