# %%
import numpy as np
import cvxpy as cp
import numpy as np
import pandas as pd
import time
from scipy.optimize import minimize
import random

# 行動分類のラベル
large = ["必需行動", "拘束行動", "自由行動", "その他"] # 大分類
 
middle = ["睡眠", "食事", "身のまわりの用事", "療養・静養", "仕事", "仕事関連", "学業", "学校外の学習", 
  "家事", "子どもの世話", "家庭雑事", "通勤", "通学", "社会参加", "会話・交際", "スポーツ", 
  "行楽・散策", "趣味・娯楽・教養 (インターネット除く)", "趣味・娯楽・教養のインターネット (動画除く)", 
  "インターネット動画", "テレビ", "録画番組・DVD", "ラジオ", "新聞", "雑誌・マンガ・本", "音楽", "休息", "その他", "不明"]
 # 中分類
 
small = ["睡眠", "食事", "身のまわりの用事", "療養・静養", "仕事", "仕事のつきあい", "授業", "学校外の学習", 
  "炊事・掃除・洗濯", "買い物", "子どもの世話", "家庭雑事", "通勤", "通学", "社会参加", "会話・交際", 
  "スポーツ", "行楽・散策", "趣味・娯楽・教養 (インターネット除く)", "趣味・娯楽・教養のインターネット (動画除く)", 
  "インターネット動画", "テレビ", "録画番組・DVD", "ラジオ", "新聞", "雑誌・マンガ・本", "音楽", "休息", "その他", "不明"]
 # 小分類

def calc_list_diff(list1:list, list2:list):
    # リストの長さが異なる場合のエラーチェック
    if len(list1) != len(list2):
        raise ValueError("リストの長さが異なります。")
    
    # 各要素の差分を計算して新しいリストを生成
    difference = [a - b for a, b in zip(list1, list2)]
    return difference

# not P_iの計算
def get_P_i(Initial_P_i,Transition_rates,Daily_table):
    # 初期の行為者率ベクトル（例としてランダムに設定）
    initial_rate = np.array(Initial_P_i)

    # 正規化
    initial_rate = initial_rate / np.sum(initial_rate)

    P_i_list = []
    for i in range(len(Daily_table)):

        # 行列の加工
        n = len(initial_rate)
        one_vector = np.ones(n)
        modified_transition_rates = []

        for A in Transition_rates:
            A_i = A.copy()
            A_i[i, :] = 0  # 行 i を全て 0 に置き換える
            modified_transition_rates.append(A_i)

        # 初期行為者率ベクトルの加工
        modified_initial_rate = initial_rate.copy()
        modified_initial_rate[i] = 0

        # 最終的な行為者率ベクトルの計算
        final_rate = modified_initial_rate

        for A_i in modified_transition_rates:
            final_rate = A_i @ final_rate

        # 行為 i を一度も行わない確率の計算
        P_not_i = one_vector @ final_rate

        P_i = 1-P_not_i

        P_i_list.append(P_i)

    return P_i_list

# 遷移確率の計算
def calc_transition_rates(no_of_elem:int,beta_i:np.ndarray,time_list:list,time_table:pd.DataFrame):

    transition_rates = []
    for i in range(len(time_list)):
        time_t      = time_list[i]
        time_t1     = time_list[(i+1)%24]
        y_t     = np.array(time_table.query("Time == @time_t")["Rate"])
        y_t1    = np.array(time_table.query("Time == @time_t1")["Rate"])

        # 変数の定義
        a = cp.Variable((no_of_elem, no_of_elem), nonneg=True)  # 非負制約を持つ変数行列

        # パラメータの設定
        delta = np.eye(no_of_elem)  # クロネッカーのデルタ

        # 目的関数の定義（要素ごとの積を使用）
        objective = cp.Minimize(cp.sum(cp.multiply(1 - beta_i[:, None] * delta, cp.square(a))))

        # 制約条件の定義
        constraints = [
            cp.sum(a, axis=0) == 1,  # 制約 (6b)
            a >= 0,  # 制約 (6c)
        ]

        # 正規化
        y_t = y_t / np.sum(y_t)
        y_t1 = y_t1 / np.sum(y_t1)

        # 制約 (6d)
        constraints.append(y_t1 - a @ y_t == 0)

        # 問題の定義と解法
        problem = cp.Problem(objective, constraints)
        problem.solve()

        # 結果の格納
        transition_rates.append(a.value)

    return transition_rates

def roulette_wheel_selection(weights):
    """
    Performs roulette wheel selection on a list of weights.
    
    Args:
    weights (list of float): The weights or probabilities for each item.
    
    Returns:
    int: The index of the selected item.
    """
    # Calculate the cumulative sum of weights
    cumulative_sum = [sum(weights[:i+1]) for i in range(len(weights))]
    total_sum = cumulative_sum[-1]
    
    # Generate a random number in the range [0, total_sum)
    random_num = random.uniform(0, total_sum)
    
    # Find the index where the random number would fit in the cumulative sum
    for i, cum_sum in enumerate(cumulative_sum):
        if random_num < cum_sum:
            return i

# %%
"""国民生活時間調査のデータからの成型"""
# daily
daily_df = pd.read_csv('2020_4shihyo_all.csv')
daily_df = daily_df.set_axis(["Day","Group","Activity","Rate","AvgTimeAct","AvgTimeAll","StdDevAll"],axis=1)
daily_df["Rate"] = daily_df["Rate"]/100
# daily_table = daily_df.query("Day == '平日' and Group == '男１０代'").query(f"Activity in @middle").filter(items=["Activity","Rate"])
daily_table = daily_df.query("Day == '平日'").query(f"Activity in @middle").filter(items=["Activity","Rate"])
# time
time_df = pd.read_csv('2020_jikoku_all.csv')
time_df = time_df.set_axis(["Day","Group","Activity","Time","Rate"],axis=1)
time_df["Rate"] = time_df["Rate"]/100
# time_table = time_df.query("Day == '平日' and Group == '男１０代'").query(f"Activity in @middle").filter(items=["Activity","Time","Rate"])
time_table = time_df.query("Day == '平日'").query(f"Activity in @middle").filter(items=["Activity","Time","Rate"])
# get time list
time_list = list(time_table["Time"].unique())

orig_P_i = daily_table["Rate"].to_list() # オリジナルの一日の行為者率

# %%
"""SA法によるβのパラメータフィッティング(事前知識なし)"""
def objective(N,Beta,Time_list,Time_table,Daily_table,Orig_P_i):
    transition_rates = calc_transition_rates(N,Beta,Time_list,Time_table)
    initial_P_i = time_table.query("Time == '0:00'")["Rate"].to_list()
    calclated_P_i = get_P_i(initial_P_i,transition_rates,Daily_table)
    diff_2 = sum([e**2 for e in calc_list_diff(Orig_P_i,calclated_P_i)])
    return diff_2

def simulated_annealing(objective, bounds, n_iterations, step_size, temp, actN, time_list, time_table, daily_table,orig_P_i):
    # 初期解を生成
    initial_beta = np.random.uniform(bounds[:, 0], bounds[:, 1])
    # 初期評価値を計算
    best_eval = objective(actN,initial_beta,time_list,time_table,daily_table,orig_P_i)
    curr, curr_eval = initial_beta, best_eval
    
    for i in range(n_iterations):
        # 新しい候補解を生成
        candidate = curr + np.random.uniform(-step_size, step_size, len(bounds))
        # 境界チェック
        candidate = np.clip(candidate, bounds[:, 0], bounds[:, 1])
        # 新しい評価値を計算
        candidate_eval = objective(actN,candidate,time_list,time_table,daily_table,orig_P_i)
        # 温度の減衰
        t = temp / float(i + 1)
        # 新しい解を受け入れるかの確率を計算
        if candidate_eval < curr_eval or np.exp((curr_eval - candidate_eval) / t) > np.random.rand():
            curr, curr_eval = candidate, candidate_eval
        # ベスト解を更新
        if candidate_eval < best_eval:
            best, best_eval = candidate, candidate_eval
            print(f"Iteration {i+1}, Best Evaluation: {best_eval}")

    return best, best_eval

# パラメータの設定
act_n = len(daily_table) # 行為の分類数
print("number of acitivities is "+str(act_n))

bounds = np.array([[0.0,1.0] for i in range(act_n)])
n_iterations = 1000
step_size = 0.1
temp = 100.0

# 最適化の実行
best_solution, best_evaluation = simulated_annealing(objective, bounds, n_iterations, step_size, temp, act_n, time_list, time_table, daily_table, orig_P_i)

print(f'Best Solution: {best_solution}')
print(f'Best Evaluation: {best_evaluation}')
# Out:
# number of acitivities is 24
# Iteration 12, Best Evaluation: 0.7288613690623583
# Iteration 25, Best Evaluation: 0.6794394021624456
# Iteration 31, Best Evaluation: 0.6653627014580581
# Iteration 34, Best Evaluation: 0.6324872194233818
# Iteration 35, Best Evaluation: 0.5889857513841759
# Iteration 36, Best Evaluation: 0.5352596188998077
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[139], line 45
#      42 temp = 100.0
#      44 # 最適化の実行
# ---> 45 best_solution, best_evaluation = simulated_annealing(objective, bounds, n_iterations, step_size, temp, act_n, time_list, time_table, daily_table, orig_P_i)
#      47 print(f'Best Solution: {best_solution}')
#      48 print(f'Best Evaluation: {best_evaluation}')
#
# Cell In[139], line 22, in simulated_annealing(objective, bounds, n_iterations, step_size, temp, actN, time_list, time_table, daily_table, orig_P_i)
#      20 candidate = np.clip(candidate, bounds[:, 0], bounds[:, 1])
#      21 # 新しい評価値を計算
# ---> 22 candidate_eval = objective(actN,candidate,time_list,time_table,daily_table,orig_P_i)
#      23 # 温度の減衰
#      24 t = temp / float(i + 1)
#
# Cell In[139], line 3, in objective(N, Beta, Time_list, Time_table, Daily_table, Orig_P_i)
#       2 def objective(N,Beta,Time_list,Time_table,Daily_table,Orig_P_i):
# ----> 3     transition_rates = calc_transition_rates(N,Beta,Time_list,Time_table)
#       4     initial_P_i = time_table.query("Time == '0:00'")["Rate"].to_list()
#       5     calclated_P_i = get_P_i(initial_P_i,transition_rates,Daily_table)
#
# Cell In[137], line 107, in calc_transition_rates(no_of_elem, beta_i, time_list, time_table)
#     105 # 問題の定義と解法
#     106 problem = cp.Problem(objective, constraints)
# --> 107 problem.solve()
#     109 # 結果の格納
#     110 transition_rates.append(a.value)
#
# File c:\Users\tora2\anaconda3\envs\geo_env\Lib\site-packages\cvxpy\problems\problem.py:503, in Problem.solve(self, *args, **kwargs)
#     501 else:
#     502     solve_func = Problem._solve
# --> 503 return solve_func(self, *args, **kwargs)
#
# File c:\Users\tora2\anaconda3\envs\geo_env\Lib\site-packages\cvxpy\problems\problem.py:1086, in Problem._solve(self, solver, warm_start, verbose, gp, qcp, requires_grad, enforce_dpp, ignore_dpp, canon_backend, **kwargs)
#    1084 if solver_verbose and (not verbose):
#    1085     print(_NUM_SOLVER_STR)
# -> 1086 solution = solving_chain.solve_via_data(
#    1087     self, data, warm_start, solver_verbose, kwargs)
#    1088 end = time.time()
#    1089 self._solve_time = end - start
#
# File c:\Users\tora2\anaconda3\envs\geo_env\Lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:475, in SolvingChain.solve_via_data(self, problem, data, warm_start, verbose, solver_opts)
#     439 def solve_via_data(self, problem, data, warm_start: bool = False, verbose: bool = False,
#     440                    solver_opts={}):
#     441     """Solves the problem using the data output by the an apply invocation.
#     442
#     443     The semantics are:
#    (...)
#     473         a Solution object.
#     474     """
# --> 475     return self.solver.solve_via_data(data, warm_start, verbose,
#     476                                       solver_opts, problem._solver_cache)
#
# File c:\Users\tora2\anaconda3\envs\geo_env\Lib\site-packages\cvxpy\reductions\solvers\conic_solvers\clarabel_conif.py:332, in CLARABEL.solve_via_data(self, data, warm_start, verbose, solver_opts, solver_cache)
#     328     return _results, _results.status
#     330 results, status = solve(solver_opts)
# --> 332 if solver_cache is not None and self.STATUS_MAP[str(status)]:
#     333     solver_cache[self.name()] = results
#     335 return results
#
# KeyboardInterrupt:

# %%
"""SA法によるβのパラメータフィッティング(事前知識加味)"""
def objective(N,Beta,Time_list,Time_table,Daily_table,Orig_P_i):
    transition_rates = calc_transition_rates(N,Beta,Time_list,Time_table)
    initial_P_i = time_table.query("Time == '0:00'")["Rate"].to_list()
    calclated_P_i = get_P_i(initial_P_i,transition_rates,Daily_table)
    diff_1 = [e for e in calc_list_diff(Orig_P_i,calclated_P_i)]
    diff_2 = sum([e**2 for e in diff_1])
    return diff_2,diff_1

def simulated_annealing(objective, bounds, n_iterations, step_size, temp, actN, time_list, time_table, daily_table,orig_P_i):
    # 初期解を生成
    initial_beta = np.random.uniform(bounds[:, 0], bounds[:, 1])
    # 初期評価値を計算
    best_eval, best_eval_raw= objective(actN,initial_beta,time_list,time_table,daily_table,orig_P_i)
    curr, curr_eval = initial_beta, best_eval
    
    for i in range(n_iterations):
        # 新しい候補解を生成
        candidate = curr + np.random.uniform(-step_size, step_size, len(bounds))
        """候補を事前知識から補正(βは大きいほど同行為の継続確率が大きくなる)"""
        candidate_updated = []
        for candidate_,eval_ in zip(list(candidate),best_eval_raw):
            new_candidate = 0
            if (eval_ > 0): # オリジナルの行為者率よりも高い場合→遷移しすぎ→βを小さく(遷移のしやすさを抑制)
                new_candidate = abs(candidate_)*(-1)
            elif (eval_ < 0): # オリジナルの行為者率よりも低い場合→遷移しなさすぎ→βを大きく(遷移のしやすさを促進)
                new_candidate = abs(candidate_)   
            else:
                new_candidate = candidate_
            candidate_updated.append(new_candidate)
        candidate = candidate_updated

        # 境界チェック
        candidate = np.clip(candidate, bounds[:, 0], bounds[:, 1])
        # 新しい評価値を計算
        candidate_eval, candidate_eval_raw = objective(actN,candidate,time_list,time_table,daily_table,orig_P_i)
        # 温度の減衰
        t = temp / float(i + 1)
        # 新しい解を受け入れるかの確率を計算
        if candidate_eval < curr_eval or np.exp((curr_eval - candidate_eval) / t) > np.random.rand():
            curr, curr_eval = candidate, candidate_eval
        # ベスト解を更新
        if candidate_eval < best_eval:
            best, best_eval, best_eval_raw = candidate, candidate_eval, candidate_eval_raw
        print(f"Iteration {i+1}, Best Evaluation: {best_eval}")

    return best, best_eval

# パラメータの設定
act_n = len(daily_table) # 行為の分類数
print("number of acitivities is "+str(act_n))

bounds = np.array([[0.0,1.0] for i in range(act_n)])
n_iterations = 500
step_size = 0.1
temp = 100.0

# 最適化の実行
best_solution, best_evaluation = simulated_annealing(objective, bounds, n_iterations, step_size, temp, act_n, time_list, time_table, daily_table, orig_P_i)

print(f'Best Solution: {best_solution}')
print(f'Best Evaluation: {best_evaluation}')
# Out:
# number of acitivities is 24
# Iteration 1, Best Evaluation: 0.6268198663524098
# Iteration 2, Best Evaluation: 0.6268198663524098
# Iteration 3, Best Evaluation: 0.6268198663524098
# Iteration 4, Best Evaluation: 0.6268198663524098
# Iteration 5, Best Evaluation: 0.6268198663524098
# Iteration 6, Best Evaluation: 0.6268198663524098
# Iteration 7, Best Evaluation: 0.6268198663524098
# Iteration 8, Best Evaluation: 0.6268198663524098
# Iteration 9, Best Evaluation: 0.6268198663524098
# Iteration 10, Best Evaluation: 0.6268198663524098
# Iteration 11, Best Evaluation: 0.6268198663524098
# Iteration 12, Best Evaluation: 0.6082690490774157
# Iteration 13, Best Evaluation: 0.6082690490774157
# Iteration 14, Best Evaluation: 0.583776562166655
# Iteration 15, Best Evaluation: 0.5516767990524535
# Iteration 16, Best Evaluation: 0.5331316686158137
# Iteration 17, Best Evaluation: 0.5331316686158137
# Iteration 18, Best Evaluation: 0.5331316686158137
# Iteration 19, Best Evaluation: 0.5331316686158137
# Iteration 20, Best Evaluation: 0.5331316686158137
# Iteration 21, Best Evaluation: 0.5331316686158137
# Iteration 22, Best Evaluation: 0.5331316686158137
# Iteration 23, Best Evaluation: 0.5331316686158137
# Iteration 24, Best Evaluation: 0.5331316686158137
# Iteration 25, Best Evaluation: 0.5331316686158137
# Iteration 26, Best Evaluation: 0.5331316686158137
# Iteration 27, Best Evaluation: 0.5331316686158137
# Iteration 28, Best Evaluation: 0.5331316686158137
# Iteration 29, Best Evaluation: 0.5331316686158137
# Iteration 30, Best Evaluation: 0.5331316686158137
# Iteration 31, Best Evaluation: 0.5331316686158137
# Iteration 32, Best Evaluation: 0.5331316686158137
# Iteration 33, Best Evaluation: 0.5331316686158137
# Iteration 34, Best Evaluation: 0.5331316686158137
# Iteration 35, Best Evaluation: 0.5331316686158137
# Iteration 36, Best Evaluation: 0.5331316686158137
# Iteration 37, Best Evaluation: 0.5331316686158137
# Iteration 38, Best Evaluation: 0.5331316686158137
# Iteration 39, Best Evaluation: 0.5331316686158137
# Iteration 40, Best Evaluation: 0.5331316686158137
# Iteration 41, Best Evaluation: 0.5331316686158137
# Iteration 42, Best Evaluation: 0.5331316686158137
# Iteration 43, Best Evaluation: 0.5331316686158137
# Iteration 44, Best Evaluation: 0.5331316686158137
# Iteration 45, Best Evaluation: 0.5331316686158137
# Iteration 46, Best Evaluation: 0.5331316686158137
# Iteration 47, Best Evaluation: 0.5331316686158137
# Iteration 48, Best Evaluation: 0.5331316686158137
# Iteration 49, Best Evaluation: 0.5331316686158137
# Iteration 50, Best Evaluation: 0.5331316686158137
# Iteration 51, Best Evaluation: 0.5331316686158137
# Iteration 52, Best Evaluation: 0.5331316686158137
# Iteration 53, Best Evaluation: 0.5331316686158137
# Iteration 54, Best Evaluation: 0.5331316686158137
# Iteration 55, Best Evaluation: 0.5331316686158137
# Iteration 56, Best Evaluation: 0.5331316686158137
# Iteration 57, Best Evaluation: 0.5331316686158137
# Iteration 58, Best Evaluation: 0.5331316686158137
# Iteration 59, Best Evaluation: 0.5331316686158137
# Iteration 60, Best Evaluation: 0.5331316686158137
# Iteration 61, Best Evaluation: 0.5331316686158137
# Iteration 62, Best Evaluation: 0.5331316686158137
# Iteration 63, Best Evaluation: 0.5331316686158137
# Iteration 64, Best Evaluation: 0.5331316686158137
# Iteration 65, Best Evaluation: 0.5331316686158137
# Iteration 66, Best Evaluation: 0.5331316686158137
# Iteration 67, Best Evaluation: 0.5331316686158137
# Iteration 68, Best Evaluation: 0.5331316686158137
# Iteration 69, Best Evaluation: 0.5331316686158137
# Iteration 70, Best Evaluation: 0.5331316686158137
# Iteration 71, Best Evaluation: 0.5331316686158137
# Iteration 72, Best Evaluation: 0.5331316686158137
# Iteration 73, Best Evaluation: 0.5331316686158137
# Iteration 74, Best Evaluation: 0.5331316686158137
# Iteration 75, Best Evaluation: 0.5331316686158137
# Iteration 76, Best Evaluation: 0.5331316686158137
# Iteration 77, Best Evaluation: 0.5331316686158137
# Iteration 78, Best Evaluation: 0.5331316686158137
# Iteration 79, Best Evaluation: 0.5331316686158137
# Iteration 80, Best Evaluation: 0.5331316686158137
# Iteration 81, Best Evaluation: 0.5331316686158137
# Iteration 82, Best Evaluation: 0.5331316686158137
# Iteration 83, Best Evaluation: 0.5331316686158137
# Iteration 84, Best Evaluation: 0.5331316686158137
# Iteration 85, Best Evaluation: 0.5331316686158137
# Iteration 86, Best Evaluation: 0.5331316686158137
# Iteration 87, Best Evaluation: 0.5331316686158137
# Iteration 88, Best Evaluation: 0.5331316686158137
# Iteration 89, Best Evaluation: 0.5331316686158137
# Iteration 90, Best Evaluation: 0.5331316686158137
# Iteration 91, Best Evaluation: 0.5331316686158137
# Iteration 92, Best Evaluation: 0.5331316686158137
# Iteration 93, Best Evaluation: 0.5331316686158137
# Iteration 94, Best Evaluation: 0.5331316686158137
# Iteration 95, Best Evaluation: 0.5331316686158137
# Iteration 96, Best Evaluation: 0.5331316686158137
# Iteration 97, Best Evaluation: 0.5331316686158137
# Iteration 98, Best Evaluation: 0.5331316686158137
# Iteration 99, Best Evaluation: 0.5331316686158137
# Iteration 100, Best Evaluation: 0.5331316686158137
# Iteration 101, Best Evaluation: 0.5331316686158137
# Iteration 102, Best Evaluation: 0.5331316686158137
# Iteration 103, Best Evaluation: 0.5331316686158137
# Iteration 104, Best Evaluation: 0.5331316686158137
# Iteration 105, Best Evaluation: 0.5331316686158137
# Iteration 106, Best Evaluation: 0.5331316686158137
# Iteration 107, Best Evaluation: 0.5331316686158137
# Iteration 108, Best Evaluation: 0.5331316686158137
# Iteration 109, Best Evaluation: 0.5331316686158137
# Iteration 110, Best Evaluation: 0.5331316686158137
# Iteration 111, Best Evaluation: 0.5331316686158137
# Iteration 112, Best Evaluation: 0.5331316686158137
# Iteration 113, Best Evaluation: 0.5331316686158137
# Iteration 114, Best Evaluation: 0.5331316686158137
# Iteration 115, Best Evaluation: 0.5331316686158137
# Iteration 116, Best Evaluation: 0.5331316686158137
# Iteration 117, Best Evaluation: 0.5331316686158137
# Iteration 118, Best Evaluation: 0.5331316686158137
# Iteration 119, Best Evaluation: 0.5331316686158137
# Iteration 120, Best Evaluation: 0.5331316686158137
# Iteration 121, Best Evaluation: 0.5331316686158137
# Iteration 122, Best Evaluation: 0.5331316686158137
# Iteration 123, Best Evaluation: 0.5331316686158137
# Iteration 124, Best Evaluation: 0.5331316686158137
# Iteration 125, Best Evaluation: 0.5331316686158137
# Iteration 126, Best Evaluation: 0.5331316686158137
# Iteration 127, Best Evaluation: 0.5331316686158137
# Iteration 128, Best Evaluation: 0.5331316686158137
# Iteration 129, Best Evaluation: 0.5331316686158137
# Iteration 130, Best Evaluation: 0.5331316686158137
# Iteration 131, Best Evaluation: 0.5331316686158137
# Iteration 132, Best Evaluation: 0.5331316686158137
# Iteration 133, Best Evaluation: 0.5331316686158137
# Iteration 134, Best Evaluation: 0.5331316686158137
# Iteration 135, Best Evaluation: 0.5331316686158137
# Iteration 136, Best Evaluation: 0.5331316686158137
# Iteration 137, Best Evaluation: 0.5331316686158137
# Iteration 138, Best Evaluation: 0.5331316686158137
# Iteration 139, Best Evaluation: 0.5331316686158137
# Iteration 140, Best Evaluation: 0.5331316686158137
# Iteration 141, Best Evaluation: 0.5331316686158137
# Iteration 142, Best Evaluation: 0.5331316686158137
# Iteration 143, Best Evaluation: 0.5331316686158137
# Iteration 144, Best Evaluation: 0.5331316686158137
# Iteration 145, Best Evaluation: 0.5331316686158137
# Iteration 146, Best Evaluation: 0.5331316686158137
# Iteration 147, Best Evaluation: 0.5331316686158137
# Iteration 148, Best Evaluation: 0.5331316686158137
# Iteration 149, Best Evaluation: 0.5331316686158137
# Iteration 150, Best Evaluation: 0.5331316686158137
# Iteration 151, Best Evaluation: 0.5331316686158137
# Iteration 152, Best Evaluation: 0.5331316686158137
# Iteration 153, Best Evaluation: 0.5331316686158137
# Iteration 154, Best Evaluation: 0.5331316686158137
# Iteration 155, Best Evaluation: 0.5331316686158137
# Iteration 156, Best Evaluation: 0.5331316686158137
# Iteration 157, Best Evaluation: 0.5331316686158137
# Iteration 158, Best Evaluation: 0.5331316686158137
# Iteration 159, Best Evaluation: 0.5331316686158137
# Iteration 160, Best Evaluation: 0.5331316686158137
# Iteration 161, Best Evaluation: 0.5331316686158137
# Iteration 162, Best Evaluation: 0.5331316686158137
# Iteration 163, Best Evaluation: 0.5331316686158137
# Iteration 164, Best Evaluation: 0.5331316686158137
# Iteration 165, Best Evaluation: 0.5331316686158137
# Iteration 166, Best Evaluation: 0.5331316686158137
# Iteration 167, Best Evaluation: 0.5331316686158137
# Iteration 168, Best Evaluation: 0.5331316686158137
# Iteration 169, Best Evaluation: 0.5331316686158137
# Iteration 170, Best Evaluation: 0.5331316686158137
# Iteration 171, Best Evaluation: 0.5331316686158137
# Iteration 172, Best Evaluation: 0.5331316686158137
# Iteration 173, Best Evaluation: 0.5331316686158137
# Iteration 174, Best Evaluation: 0.5331316686158137
# Iteration 175, Best Evaluation: 0.5331316686158137
# Iteration 176, Best Evaluation: 0.5331316686158137
# Iteration 177, Best Evaluation: 0.5331316686158137
# Iteration 178, Best Evaluation: 0.5331316686158137
# Iteration 179, Best Evaluation: 0.5331316686158137
# Iteration 180, Best Evaluation: 0.5331316686158137
# Iteration 181, Best Evaluation: 0.5331316686158137
# Iteration 182, Best Evaluation: 0.5331316686158137
# Iteration 183, Best Evaluation: 0.5331316686158137
# Iteration 184, Best Evaluation: 0.5331316686158137
# Iteration 185, Best Evaluation: 0.5331316686158137
# Iteration 186, Best Evaluation: 0.5331316686158137
# Iteration 187, Best Evaluation: 0.5331316686158137
# Iteration 188, Best Evaluation: 0.5331316686158137
# Iteration 189, Best Evaluation: 0.5331316686158137
# Iteration 190, Best Evaluation: 0.5331316686158137
# Iteration 191, Best Evaluation: 0.5331316686158137
# Iteration 192, Best Evaluation: 0.5331316686158137
# Iteration 193, Best Evaluation: 0.5331316686158137
# Iteration 194, Best Evaluation: 0.5331316686158137
# Iteration 195, Best Evaluation: 0.5331316686158137
# Iteration 196, Best Evaluation: 0.5331316686158137
# Iteration 197, Best Evaluation: 0.5331316686158137
# Iteration 198, Best Evaluation: 0.5331316686158137
# Iteration 199, Best Evaluation: 0.5331316686158137
# Iteration 200, Best Evaluation: 0.5331316686158137
# Iteration 201, Best Evaluation: 0.5331316686158137
# Iteration 202, Best Evaluation: 0.5331316686158137
# Iteration 203, Best Evaluation: 0.5331316686158137
# Iteration 204, Best Evaluation: 0.5331316686158137
# Iteration 205, Best Evaluation: 0.5331316686158137
# Iteration 206, Best Evaluation: 0.5331316686158137
# Iteration 207, Best Evaluation: 0.5331316686158137
# Iteration 208, Best Evaluation: 0.5331316686158137
# Iteration 209, Best Evaluation: 0.5331316686158137
# Iteration 210, Best Evaluation: 0.5331316686158137
# Iteration 211, Best Evaluation: 0.5331316686158137
# Iteration 212, Best Evaluation: 0.5331316686158137
# Iteration 213, Best Evaluation: 0.5331316686158137
# Iteration 214, Best Evaluation: 0.5331316686158137
# Iteration 215, Best Evaluation: 0.5331316686158137
# Iteration 216, Best Evaluation: 0.5331316686158137
# Iteration 217, Best Evaluation: 0.5331316686158137
# Iteration 218, Best Evaluation: 0.5331316686158137
# Iteration 219, Best Evaluation: 0.5331316686158137
# Iteration 220, Best Evaluation: 0.5331316686158137
# Iteration 221, Best Evaluation: 0.5331316686158137
# Iteration 222, Best Evaluation: 0.5331316686158137
# Iteration 223, Best Evaluation: 0.5331316686158137
# Iteration 224, Best Evaluation: 0.5331316686158137
# Iteration 225, Best Evaluation: 0.5331316686158137
# Iteration 226, Best Evaluation: 0.5331316686158137
# Iteration 227, Best Evaluation: 0.5331316686158137
# Iteration 228, Best Evaluation: 0.5331316686158137
# Iteration 229, Best Evaluation: 0.5331316686158137
# Iteration 230, Best Evaluation: 0.5331316686158137
# Iteration 231, Best Evaluation: 0.5331316686158137
# Iteration 232, Best Evaluation: 0.5331316686158137
# Iteration 233, Best Evaluation: 0.5331316686158137
# Iteration 234, Best Evaluation: 0.5331316686158137
# Iteration 235, Best Evaluation: 0.5331316686158137
# Iteration 236, Best Evaluation: 0.5331316686158137
# Iteration 237, Best Evaluation: 0.5331316686158137
# Iteration 238, Best Evaluation: 0.5331316686158137
# Iteration 239, Best Evaluation: 0.5331316686158137
# Iteration 240, Best Evaluation: 0.5331316686158137
# Iteration 241, Best Evaluation: 0.5331316686158137
# Iteration 242, Best Evaluation: 0.5331316686158137
# Iteration 243, Best Evaluation: 0.5331316686158137
# Iteration 244, Best Evaluation: 0.5331316686158137
# Iteration 245, Best Evaluation: 0.5331316686158137
# Iteration 246, Best Evaluation: 0.5331316686158137
# Iteration 247, Best Evaluation: 0.5331316686158137
# Iteration 248, Best Evaluation: 0.5331316686158137
# Iteration 249, Best Evaluation: 0.5331316686158137
# Iteration 250, Best Evaluation: 0.5331316686158137
# Iteration 251, Best Evaluation: 0.5331316686158137
# Iteration 252, Best Evaluation: 0.5331316686158137
# Iteration 253, Best Evaluation: 0.5331316686158137
# Iteration 254, Best Evaluation: 0.5331316686158137
# Iteration 255, Best Evaluation: 0.5331316686158137
# Iteration 256, Best Evaluation: 0.5331316686158137
# Iteration 257, Best Evaluation: 0.5331316686158137
# Iteration 258, Best Evaluation: 0.5331316686158137
# Iteration 259, Best Evaluation: 0.5331316686158137
# Iteration 260, Best Evaluation: 0.5331316686158137
# Iteration 261, Best Evaluation: 0.5331316686158137
# Iteration 262, Best Evaluation: 0.5331316686158137
# Iteration 263, Best Evaluation: 0.5331316686158137
# Iteration 264, Best Evaluation: 0.5331316686158137
# Iteration 265, Best Evaluation: 0.5331316686158137
# Iteration 266, Best Evaluation: 0.5331316686158137
# Iteration 267, Best Evaluation: 0.5331316686158137
# Iteration 268, Best Evaluation: 0.5331316686158137
# Iteration 269, Best Evaluation: 0.5331316686158137
# Iteration 270, Best Evaluation: 0.5331316686158137
# Iteration 271, Best Evaluation: 0.5331316686158137
# Iteration 272, Best Evaluation: 0.5331316686158137
# Iteration 273, Best Evaluation: 0.5331316686158137
# Iteration 274, Best Evaluation: 0.5331316686158137
# Iteration 275, Best Evaluation: 0.5331316686158137
# Iteration 276, Best Evaluation: 0.5331316686158137
# Iteration 277, Best Evaluation: 0.5331316686158137
# Iteration 278, Best Evaluation: 0.5331316686158137
# Iteration 279, Best Evaluation: 0.5331316686158137
# Iteration 280, Best Evaluation: 0.5331316686158137
# Iteration 281, Best Evaluation: 0.5331316686158137
# Iteration 282, Best Evaluation: 0.5331316686158137
# Iteration 283, Best Evaluation: 0.5331316686158137
# Iteration 284, Best Evaluation: 0.5331316686158137
# Iteration 285, Best Evaluation: 0.5331316686158137
# Iteration 286, Best Evaluation: 0.5331316686158137
# Iteration 287, Best Evaluation: 0.5331316686158137
# Iteration 288, Best Evaluation: 0.5331316686158137
# Iteration 289, Best Evaluation: 0.5331316686158137
# Iteration 290, Best Evaluation: 0.5331316686158137
# Iteration 291, Best Evaluation: 0.5331316686158137
# Iteration 292, Best Evaluation: 0.5331316686158137
# Iteration 293, Best Evaluation: 0.5331316686158137
# Iteration 294, Best Evaluation: 0.5331316686158137
# Iteration 295, Best Evaluation: 0.5331316686158137
# Iteration 296, Best Evaluation: 0.5331316686158137
# Iteration 297, Best Evaluation: 0.5331316686158137
# Iteration 298, Best Evaluation: 0.5331316686158137
# Iteration 299, Best Evaluation: 0.5331316686158137
# Iteration 300, Best Evaluation: 0.5331316686158137
# Iteration 301, Best Evaluation: 0.5331316686158137
# Iteration 302, Best Evaluation: 0.5331316686158137
# Iteration 303, Best Evaluation: 0.5331316686158137
# Iteration 304, Best Evaluation: 0.5331316686158137
# Iteration 305, Best Evaluation: 0.5331316686158137
# Iteration 306, Best Evaluation: 0.5331316686158137
# Iteration 307, Best Evaluation: 0.5331316686158137
# Iteration 308, Best Evaluation: 0.5331316686158137
# Iteration 309, Best Evaluation: 0.5331316686158137
# Iteration 310, Best Evaluation: 0.5331316686158137
# Iteration 311, Best Evaluation: 0.5331316686158137
# Iteration 312, Best Evaluation: 0.5331316686158137
# Iteration 313, Best Evaluation: 0.5331316686158137
# Iteration 314, Best Evaluation: 0.5331316686158137
# Iteration 315, Best Evaluation: 0.5331316686158137
# Iteration 316, Best Evaluation: 0.5331316686158137
# Iteration 317, Best Evaluation: 0.5331316686158137
# Iteration 318, Best Evaluation: 0.5331316686158137
# Iteration 319, Best Evaluation: 0.5331316686158137
# Iteration 320, Best Evaluation: 0.5331316686158137
# Iteration 321, Best Evaluation: 0.5331316686158137
# Iteration 322, Best Evaluation: 0.5331316686158137
# Iteration 323, Best Evaluation: 0.5331316686158137
# Iteration 324, Best Evaluation: 0.5331316686158137
# Iteration 325, Best Evaluation: 0.5331316686158137
# Iteration 326, Best Evaluation: 0.5331316686158137
# Iteration 327, Best Evaluation: 0.5331316686158137
# Iteration 328, Best Evaluation: 0.5331316686158137
# Iteration 329, Best Evaluation: 0.5331316686158137
# Iteration 330, Best Evaluation: 0.5331316686158137
# Iteration 331, Best Evaluation: 0.5331316686158137
# Iteration 332, Best Evaluation: 0.5331316686158137
# Iteration 333, Best Evaluation: 0.5331316686158137
# Iteration 334, Best Evaluation: 0.5331316686158137
# Iteration 335, Best Evaluation: 0.5331316686158137
# Iteration 336, Best Evaluation: 0.5331316686158137
# Iteration 337, Best Evaluation: 0.5331316686158137
# Iteration 338, Best Evaluation: 0.5331316686158137
# Iteration 339, Best Evaluation: 0.5331316686158137
# Iteration 340, Best Evaluation: 0.5331316686158137
# Iteration 341, Best Evaluation: 0.5331316686158137
# Iteration 342, Best Evaluation: 0.5331316686158137
# Iteration 343, Best Evaluation: 0.5331316686158137
# Iteration 344, Best Evaluation: 0.5331316686158137
# Iteration 345, Best Evaluation: 0.5331316686158137
# Iteration 346, Best Evaluation: 0.5331316686158137
# Iteration 347, Best Evaluation: 0.5331316686158137
# Iteration 348, Best Evaluation: 0.5331316686158137
# Iteration 349, Best Evaluation: 0.5331316686158137
# Iteration 350, Best Evaluation: 0.5331316686158137
# Iteration 351, Best Evaluation: 0.5331316686158137
# Iteration 352, Best Evaluation: 0.5331316686158137
# Iteration 353, Best Evaluation: 0.5331316686158137
# Iteration 354, Best Evaluation: 0.5331316686158137
# Iteration 355, Best Evaluation: 0.5331316686158137
# Iteration 356, Best Evaluation: 0.5331316686158137
# Iteration 357, Best Evaluation: 0.5331316686158137
# Iteration 358, Best Evaluation: 0.5331316686158137
# Iteration 359, Best Evaluation: 0.5331316686158137
# Iteration 360, Best Evaluation: 0.5331316686158137
# Iteration 361, Best Evaluation: 0.5331316686158137
# Iteration 362, Best Evaluation: 0.5331316686158137
# Iteration 363, Best Evaluation: 0.5331316686158137
# Iteration 364, Best Evaluation: 0.5331316686158137
# Iteration 365, Best Evaluation: 0.5331316686158137
# Iteration 366, Best Evaluation: 0.5331316686158137
# Iteration 367, Best Evaluation: 0.5331316686158137
# Iteration 368, Best Evaluation: 0.5331316686158137
# Iteration 369, Best Evaluation: 0.5331316686158137
# Iteration 370, Best Evaluation: 0.5331316686158137
# Iteration 371, Best Evaluation: 0.5331316686158137
# Iteration 372, Best Evaluation: 0.5331316686158137
# Iteration 373, Best Evaluation: 0.5331316686158137
# Iteration 374, Best Evaluation: 0.5331316686158137
# Iteration 375, Best Evaluation: 0.5331316686158137
# Iteration 376, Best Evaluation: 0.5331316686158137
# Iteration 377, Best Evaluation: 0.5331316686158137
# Iteration 378, Best Evaluation: 0.5331316686158137
# Iteration 379, Best Evaluation: 0.5331316686158137
# Iteration 380, Best Evaluation: 0.5331316686158137
# Iteration 381, Best Evaluation: 0.5331316686158137
# Iteration 382, Best Evaluation: 0.5331316686158137
# Iteration 383, Best Evaluation: 0.5331316686158137
# Iteration 384, Best Evaluation: 0.5331316686158137
# Iteration 385, Best Evaluation: 0.5331316686158137
# Iteration 386, Best Evaluation: 0.5331316686158137
# Iteration 387, Best Evaluation: 0.5331316686158137
# Iteration 388, Best Evaluation: 0.5331316686158137
# Iteration 389, Best Evaluation: 0.5331316686158137
# Iteration 390, Best Evaluation: 0.5331316686158137
# Iteration 391, Best Evaluation: 0.5331316686158137
# Iteration 392, Best Evaluation: 0.5331316686158137
# Iteration 393, Best Evaluation: 0.5331316686158137
# Iteration 394, Best Evaluation: 0.5331316686158137
# Iteration 395, Best Evaluation: 0.5331316686158137
# Iteration 396, Best Evaluation: 0.5331316686158137
# Iteration 397, Best Evaluation: 0.5331316686158137
# Iteration 398, Best Evaluation: 0.5331316686158137
# Iteration 399, Best Evaluation: 0.5331316686158137
# Iteration 400, Best Evaluation: 0.5331316686158137
# Iteration 401, Best Evaluation: 0.5331316686158137
# Iteration 402, Best Evaluation: 0.5331316686158137
# Iteration 403, Best Evaluation: 0.5331316686158137
# Iteration 404, Best Evaluation: 0.5331316686158137
# Iteration 405, Best Evaluation: 0.5331316686158137
# Iteration 406, Best Evaluation: 0.5331316686158137
# Iteration 407, Best Evaluation: 0.5331316686158137
# Iteration 408, Best Evaluation: 0.5331316686158137
# Iteration 409, Best Evaluation: 0.5331316686158137
# Iteration 410, Best Evaluation: 0.5331316686158137
# Iteration 411, Best Evaluation: 0.5331316686158137
# Iteration 412, Best Evaluation: 0.5331316686158137
# Iteration 413, Best Evaluation: 0.5331316686158137
# Iteration 414, Best Evaluation: 0.5331316686158137
# Iteration 415, Best Evaluation: 0.5331316686158137
# Iteration 416, Best Evaluation: 0.5331316686158137
# Iteration 417, Best Evaluation: 0.5331316686158137
# Iteration 418, Best Evaluation: 0.5331316686158137
# Iteration 419, Best Evaluation: 0.5331316686158137
# Iteration 420, Best Evaluation: 0.5331316686158137
# Iteration 421, Best Evaluation: 0.5331316686158137
# Iteration 422, Best Evaluation: 0.5331316686158137
# Iteration 423, Best Evaluation: 0.5318044245987751
# Iteration 424, Best Evaluation: 0.5318044245987751
# Iteration 425, Best Evaluation: 0.5318044245987751
# Iteration 426, Best Evaluation: 0.5318044245987751
# Iteration 427, Best Evaluation: 0.5318044245987751
# Iteration 428, Best Evaluation: 0.5318044245987751
# Iteration 429, Best Evaluation: 0.5308611285618929
# Iteration 430, Best Evaluation: 0.5308611285618929
# Iteration 431, Best Evaluation: 0.5308611285618929
# Iteration 432, Best Evaluation: 0.5308611285618929
# Iteration 433, Best Evaluation: 0.5308611285618929
# Iteration 434, Best Evaluation: 0.5308611285618929
# Iteration 435, Best Evaluation: 0.5308611285618929
# Iteration 436, Best Evaluation: 0.5308611285618929
# Iteration 437, Best Evaluation: 0.5308611285618929
# Iteration 438, Best Evaluation: 0.5308611285618929
# Iteration 439, Best Evaluation: 0.5308611285618929
# Iteration 440, Best Evaluation: 0.5308611285618929
# Iteration 441, Best Evaluation: 0.5308611285618929
# Iteration 442, Best Evaluation: 0.5262979681207979
# Iteration 443, Best Evaluation: 0.5262979681207979
# Iteration 444, Best Evaluation: 0.5262979681207979
# Iteration 445, Best Evaluation: 0.5262979681207979
# Iteration 446, Best Evaluation: 0.5262979681207979
# Iteration 447, Best Evaluation: 0.5262979681207979
# Iteration 448, Best Evaluation: 0.5262979681207979
# Iteration 449, Best Evaluation: 0.5262979681207979
# Iteration 450, Best Evaluation: 0.5262979681207979
# Iteration 451, Best Evaluation: 0.5164808231562927
# Iteration 452, Best Evaluation: 0.5164808231562927
# Iteration 453, Best Evaluation: 0.5164808231562927
# Iteration 454, Best Evaluation: 0.5164808231562927
# Iteration 455, Best Evaluation: 0.5069899855147368
# Iteration 456, Best Evaluation: 0.5069899855147368
# Iteration 457, Best Evaluation: 0.5069899855147368
# Iteration 458, Best Evaluation: 0.5069899855147368
# Iteration 459, Best Evaluation: 0.5069899855147368
# Iteration 460, Best Evaluation: 0.5069899855147368
# Iteration 461, Best Evaluation: 0.5069899855147368
# Iteration 462, Best Evaluation: 0.5069899855147368
# Iteration 463, Best Evaluation: 0.5069899855147368
# Iteration 464, Best Evaluation: 0.5069899855147368
# Iteration 465, Best Evaluation: 0.5069899855147368
# Iteration 466, Best Evaluation: 0.5069899855147368
# Iteration 467, Best Evaluation: 0.5069899855147368
# Iteration 468, Best Evaluation: 0.5069899855147368
# Iteration 469, Best Evaluation: 0.5069899855147368
# Iteration 470, Best Evaluation: 0.5069899855147368
# Iteration 471, Best Evaluation: 0.5069899855147368
# Iteration 472, Best Evaluation: 0.5069899855147368
# Iteration 473, Best Evaluation: 0.5069899855147368
# Iteration 474, Best Evaluation: 0.5069899855147368
# Iteration 475, Best Evaluation: 0.5069899855147368
# Iteration 476, Best Evaluation: 0.5069899855147368
# Iteration 477, Best Evaluation: 0.5069899855147368
# Iteration 478, Best Evaluation: 0.5069899855147368
# Iteration 479, Best Evaluation: 0.5069899855147368
# Iteration 480, Best Evaluation: 0.5069899855147368
# Iteration 481, Best Evaluation: 0.5069899855147368
# Iteration 482, Best Evaluation: 0.5069899855147368
# Iteration 483, Best Evaluation: 0.5069899855147368
# Iteration 484, Best Evaluation: 0.5069899855147368
# Iteration 485, Best Evaluation: 0.5069899855147368
# Iteration 486, Best Evaluation: 0.5069899855147368
# Iteration 487, Best Evaluation: 0.5069899855147368
# Iteration 488, Best Evaluation: 0.5069899855147368
# Iteration 489, Best Evaluation: 0.5069899855147368
# Iteration 490, Best Evaluation: 0.5069899855147368
# Iteration 491, Best Evaluation: 0.5069899855147368
# Iteration 492, Best Evaluation: 0.5069899855147368
# Iteration 493, Best Evaluation: 0.5069899855147368
# Iteration 494, Best Evaluation: 0.5069899855147368
# Iteration 495, Best Evaluation: 0.5069899855147368
# Iteration 496, Best Evaluation: 0.5069899855147368
# Iteration 497, Best Evaluation: 0.5069899855147368
# Iteration 498, Best Evaluation: 0.5069899855147368
# Iteration 499, Best Evaluation: 0.5069899855147368
# Iteration 500, Best Evaluation: 0.5069899855147368
# Best Solution: [0.68923324 0.         0.         0.         0.56552108 0.12056058
#  0.63979637 0.67160974 0.18092713 0.28148257 0.         0.
#  0.         0.         0.         0.         0.         0.40349906
#  0.         1.         0.         0.15892245 0.52168882 0.        ]
# Best Evaluation: 0.5069899855147368

# %%
best_solution
# Out:
# array([0.68923324, 0.        , 0.        , 0.        , 0.56552108,
#        0.12056058, 0.63979637, 0.67160974, 0.18092713, 0.28148257,
#        0.        , 0.        , 0.        , 0.        , 0.        ,
#        0.        , 0.        , 0.40349906, 0.        , 1.        ,
#        0.        , 0.15892245, 0.52168882, 0.        ])

# %%
"""算出した遷移確率から一個票を生成"""
# 推定したβをもとに遷移確率を算出
Transition_rates = calc_transition_rates(act_n,test,time_list,time_table)
# 初期行動の規定
time_table_0 = time_table.query("Time == '0:00'") # 0:00における行為者率を抽出
action_idx = roulette_wheel_selection(time_table_0["Rate"].to_list()) # その時刻における行為者率を重みとしてルーレット選択
Actions =[] # 選択した行為種別の記録
Actions.append(action_idx)
for t in range(4*24): # 15min間隔で24時間分繰り返す。
    transition_r_t = Transition_rates[t] # 時刻tの遷移確率行列を抽出
    action_idx = roulette_wheel_selection(list(transition_r_t[action_idx,:])) # 遷移確率をもとにt+1における行動種別を決定
    Actions.append(action_idx) # 行動種別履歴に追加
acts = daily_table["Activity"].to_list()
actMaster = dict(zip(list(range(len(acts))),acts))
[actMaster[a] for a in Actions]
# Out:
# ['睡眠',
#  '子どもの世話',
#  '行楽・散策',
#  '通学',
#  '社会参加',
#  'スポーツ',
#  '療養・静養',
#  '新聞',
#  '食事',
#  '通学',
#  '学校外の学習',
#  '行楽・散策',
#  '行楽・散策',
#  '社会参加',
#  '行楽・散策',
#  '社会参加',
#  'スポーツ',
#  '通学',
#  '社会参加',
#  '通学',
#  '社会参加',
#  '社会参加',
#  '通学',
#  '通学',
#  '会話・交際',
#  'インターネット動画',
#  '家庭雑事',
#  '行楽・散策',
#  '雑誌・マンガ・本',
#  '社会参加',
#  'インターネット動画',
#  '療養・静養',
#  '療養・静養',
#  '行楽・散策',
#  '会話・交際',
#  '休息',
#  'インターネット動画',
#  '社会参加',
#  '会話・交際',
#  '社会参加',
#  '雑誌・マンガ・本',
#  '雑誌・マンガ・本',
#  '社会参加',
#  '雑誌・マンガ・本',
#  '学校外の学習',
#  '通学',
#  'インターネット動画',
#  '通学',
#  '学校外の学習',
#  '新聞',
#  '音楽',
#  '社会参加',
#  '通勤',
#  '雑誌・マンガ・本',
#  '雑誌・マンガ・本',
#  '雑誌・マンガ・本',
#  '雑誌・マンガ・本',
#  '学校外の学習',
#  '音楽',
#  '社会参加',
#  '音楽',
#  '睡眠',
#  '仕事関連',
#  '社会参加',
#  '社会参加',
#  '会話・交際',
#  '食事',
#  '療養・静養',
#  'スポーツ',
#  '通学',
#  'ラジオ',
#  'ラジオ',
#  'ラジオ',
#  '雑誌・マンガ・本',
#  '会話・交際',
#  'スポーツ',
#  '雑誌・マンガ・本',
#  '雑誌・マンガ・本',
#  '療養・静養',
#  '通学',
#  '社会参加',
#  '睡眠',
#  'テレビ',
#  '通学',
#  '家庭雑事',
#  '通学',
#  'ラジオ',
#  'スポーツ',
#  '療養・静養',
#  '療養・静養',
#  'スポーツ',
#  '療養・静養',
#  'スポーツ',
#  '社会参加',
#  'スポーツ',
#  '家庭雑事',
#  '通学']
