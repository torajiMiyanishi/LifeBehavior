# %%
import os
import glob
import re
import pickle
import json
import numpy as np

# 属性と曜日のリスト
attributes = ['男１０代', '男２０代', '男３０代', '男４０代', '男５０代', '男６０代', '男７０歳以上',
              '女１０代', '女２０代', '女３０代', '女４０代', '女５０代', '女６０代', '女７０歳以上']
days = ["平日", "土曜日", "日曜日"]

def find_and_convert_all_combinations(directory):
    # パターン: 遷移確率_属性_曜日-評価値-.pickle に一致するファイルを探索
    pattern = re.compile(r'遷移確率_(.*)_(.*)-([-+]?\d*\.\d+|\d+)-\.pickle')
    
    # フォルダ内全てのpickleファイルを取得
    pickle_files = glob.glob(os.path.join(directory, '*.pickle'))
    
    for attribute in attributes:
        for day in days:
            # JSONファイルが存在しない場合のみ処理
            if not os.path.exists(os.path.join(directory, f'遷移確率_{attribute}_{day}.json')):
                # 指定された属性と曜日にマッチするファイルを探す
                matching_files = [f for f in pickle_files if f'遷移確率_{attribute}_{day}' in f]
                
                if matching_files:
                    # 評価値を考慮せず、最初のマッチングファイルを使用
                    pickle_file_path = matching_files[0]
                    
                    # JSONファイル名を設定
                    json_output_path = os.path.join(directory, f'遷移確率_{attribute}_{day}.json')
                    
                    # pickleファイルをJSONに変換
                    convert_pickle_to_json(pickle_file_path, json_output_path)
                    print(f'Converted {pickle_file_path} to {json_output_path}')
                else:
                    print(f'No matching file for {attribute} on {day}')

def convert_pickle_to_json(pickle_file_path, json_output_path):
    # Pickleファイルを読み込む
    with open(pickle_file_path, 'rb') as f:
        data = pickle.load(f)
    
    # numpy配列が含まれている場合はリストに変換（今回は三次元配列）
    if isinstance(data, np.ndarray):
        data = data.tolist()
    
    # JSONに変換して保存（指定のフォーマットで保存）
    with open(json_output_path, 'w') as json_file:
        json.dump(data, json_file, ensure_ascii=False, indent=None, separators=(',', ':'))

# 使用例
directory = 'Z:/lab/lifebehavior'  # ディレクトリのパスを指定

# 全ての組み合わせのpickleファイルを探索して変換
find_and_convert_all_combinations(directory)
# Out:
# Converted Z:/lab/lifebehavior\遷移確率_男１０代_平日-0.5756974860708636-.pickle to Z:/lab/lifebehavior\遷移確率_男１０代_平日.json
# Converted Z:/lab/lifebehavior\遷移確率_男１０代_土曜日-0.924359847926884-.pickle to Z:/lab/lifebehavior\遷移確率_男１０代_土曜日.json
# Converted Z:/lab/lifebehavior\遷移確率_男１０代_日曜日-0.9819032888775825-.pickle to Z:/lab/lifebehavior\遷移確率_男１０代_日曜日.json
# Converted Z:/lab/lifebehavior\遷移確率_男２０代_平日-0.8776047823923542-.pickle to Z:/lab/lifebehavior\遷移確率_男２０代_平日.json
# Converted Z:/lab/lifebehavior\遷移確率_男２０代_土曜日-0.9073246698912241-.pickle to Z:/lab/lifebehavior\遷移確率_男２０代_土曜日.json
# Converted Z:/lab/lifebehavior\遷移確率_男２０代_日曜日-0.9978352814341995-.pickle to Z:/lab/lifebehavior\遷移確率_男２０代_日曜日.json
# Converted Z:/lab/lifebehavior\遷移確率_男３０代_平日-0.33186452235588426-.pickle to Z:/lab/lifebehavior\遷移確率_男３０代_平日.json
# Converted Z:/lab/lifebehavior\遷移確率_男３０代_土曜日-1.2608871179788168-.pickle to Z:/lab/lifebehavior\遷移確率_男３０代_土曜日.json
# Converted Z:/lab/lifebehavior\遷移確率_男３０代_日曜日-0.9966180514704732-.pickle to Z:/lab/lifebehavior\遷移確率_男３０代_日曜日.json
# Converted Z:/lab/lifebehavior\遷移確率_男４０代_平日-0.4421202090967222-.pickle to Z:/lab/lifebehavior\遷移確率_男４０代_平日.json
# Converted Z:/lab/lifebehavior\遷移確率_男４０代_土曜日-0.8236262408710268-.pickle to Z:/lab/lifebehavior\遷移確率_男４０代_土曜日.json
# Converted Z:/lab/lifebehavior\遷移確率_男４０代_日曜日-0.8816181561894798-.pickle to Z:/lab/lifebehavior\遷移確率_男４０代_日曜日.json
# Converted Z:/lab/lifebehavior\遷移確率_男５０代_平日-0.5140584744281118-.pickle to Z:/lab/lifebehavior\遷移確率_男５０代_平日.json
# Converted Z:/lab/lifebehavior\遷移確率_男５０代_土曜日-0.8642139888981286-.pickle to Z:/lab/lifebehavior\遷移確率_男５０代_土曜日.json
# Converted Z:/lab/lifebehavior\遷移確率_男５０代_日曜日-1.2968059482784808-.pickle to Z:/lab/lifebehavior\遷移確率_男５０代_日曜日.json
# Converted Z:/lab/lifebehavior\遷移確率_男６０代_平日-1.3089478758166737-.pickle to Z:/lab/lifebehavior\遷移確率_男６０代_平日.json
# Converted Z:/lab/lifebehavior\遷移確率_男６０代_土曜日-1.812477646285025-.pickle to Z:/lab/lifebehavior\遷移確率_男６０代_土曜日.json
# Converted Z:/lab/lifebehavior\遷移確率_男６０代_日曜日-1.1381589598841482-.pickle to Z:/lab/lifebehavior\遷移確率_男６０代_日曜日.json
# Converted Z:/lab/lifebehavior\遷移確率_男７０歳以上_平日-2.0948055438733144-.pickle to Z:/lab/lifebehavior\遷移確率_男７０歳以上_平日.json
# Converted Z:/lab/lifebehavior\遷移確率_男７０歳以上_土曜日-2.2492366751246964-.pickle to Z:/lab/lifebehavior\遷移確率_男７０歳以上_土曜日.json
# Converted Z:/lab/lifebehavior\遷移確率_男７０歳以上_日曜日-2.0249247875295846-.pickle to Z:/lab/lifebehavior\遷移確率_男７０歳以上_日曜日.json
# Converted Z:/lab/lifebehavior\遷移確率_女１０代_平日-0.5038263861810057-.pickle to Z:/lab/lifebehavior\遷移確率_女１０代_平日.json
# Converted Z:/lab/lifebehavior\遷移確率_女１０代_土曜日-0.7133805785252096-.pickle to Z:/lab/lifebehavior\遷移確率_女１０代_土曜日.json
# Converted Z:/lab/lifebehavior\遷移確率_女１０代_日曜日-0.9241855699585887-.pickle to Z:/lab/lifebehavior\遷移確率_女１０代_日曜日.json
# Converted Z:/lab/lifebehavior\遷移確率_女２０代_平日-0.4384363159064976-.pickle to Z:/lab/lifebehavior\遷移確率_女２０代_平日.json
# Converted Z:/lab/lifebehavior\遷移確率_女２０代_土曜日-0.7733746814454263-.pickle to Z:/lab/lifebehavior\遷移確率_女２０代_土曜日.json
# Converted Z:/lab/lifebehavior\遷移確率_女２０代_日曜日-0.8756963769971267-.pickle to Z:/lab/lifebehavior\遷移確率_女２０代_日曜日.json
# Converted Z:/lab/lifebehavior\遷移確率_女３０代_平日-1.0959370073419834-.pickle to Z:/lab/lifebehavior\遷移確率_女３０代_平日.json
# Converted Z:/lab/lifebehavior\遷移確率_女３０代_土曜日-1.0395095287385514-.pickle to Z:/lab/lifebehavior\遷移確率_女３０代_土曜日.json
# Converted Z:/lab/lifebehavior\遷移確率_女３０代_日曜日-0.8332657757361516-.pickle to Z:/lab/lifebehavior\遷移確率_女３０代_日曜日.json
# Converted Z:/lab/lifebehavior\遷移確率_女４０代_平日-1.4867569756720416-.pickle to Z:/lab/lifebehavior\遷移確率_女４０代_平日.json
# Converted Z:/lab/lifebehavior\遷移確率_女４０代_土曜日-1.186897168214167-.pickle to Z:/lab/lifebehavior\遷移確率_女４０代_土曜日.json
# Converted Z:/lab/lifebehavior\遷移確率_女４０代_日曜日-0.7502508061594704-.pickle to Z:/lab/lifebehavior\遷移確率_女４０代_日曜日.json
# Converted Z:/lab/lifebehavior\遷移確率_女５０代_平日-1.4097490488004212-.pickle to Z:/lab/lifebehavior\遷移確率_女５０代_平日.json
# Converted Z:/lab/lifebehavior\遷移確率_女５０代_土曜日-1.0266840529391847-.pickle to Z:/lab/lifebehavior\遷移確率_女５０代_土曜日.json
# Converted Z:/lab/lifebehavior\遷移確率_女５０代_日曜日-1.1076311519132271-.pickle to Z:/lab/lifebehavior\遷移確率_女５０代_日曜日.json
# Converted Z:/lab/lifebehavior\遷移確率_女６０代_平日-1.6712448675021399-.pickle to Z:/lab/lifebehavior\遷移確率_女６０代_平日.json
# Converted Z:/lab/lifebehavior\遷移確率_女６０代_土曜日-1.5940307137258132-.pickle to Z:/lab/lifebehavior\遷移確率_女６０代_土曜日.json
# Converted Z:/lab/lifebehavior\遷移確率_女６０代_日曜日-1.19961295042577-.pickle to Z:/lab/lifebehavior\遷移確率_女６０代_日曜日.json
# Converted Z:/lab/lifebehavior\遷移確率_女７０歳以上_平日-1.5672612876438152-.pickle to Z:/lab/lifebehavior\遷移確率_女７０歳以上_平日.json
# Converted Z:/lab/lifebehavior\遷移確率_女７０歳以上_土曜日-1.6362720292561692-.pickle to Z:/lab/lifebehavior\遷移確率_女７０歳以上_土曜日.json
# Converted Z:/lab/lifebehavior\遷移確率_女７０歳以上_日曜日-1.4494378669233692-.pickle to Z:/lab/lifebehavior\遷移確率_女７０歳以上_日曜日.json
